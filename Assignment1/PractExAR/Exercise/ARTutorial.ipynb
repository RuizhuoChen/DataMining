# %% [markdown]
# # Finding frequent itemsets and association rules
#
# ### Library: mlxtend
# We are going to use the library mlxtend which contains an implementation of the apriori algorithm. Click on the following <a href="http://rasbt.github.io/mlxtend/user_guide/frequent_patterns/association_rules/">link</a>. We recommend to install it using
#
# pip install mlxtend
#
# or
#
# conda install mlxtend
#
# Sometimes using the previous commands the library is not correctly installed, especially in the case when there are multiple Python versions installed on your Jupyter notebook. In that case, we recommend to use the command shown in the next cell (directly in your Jupyter notebook):

# %%
import sys
# !{sys.executable} -m pip install mlxtend
# Out:
# Requirement already satisfied: mlxtend in d:\anaconda\lib\site-packages (0.21.0)
# Requirement already satisfied: matplotlib>=3.0.0 in d:\anaconda\lib\site-packages (from mlxtend) (3.5.2)
# Requirement already satisfied: joblib>=0.13.2 in d:\anaconda\lib\site-packages (from mlxtend) (1.1.0)
# Requirement already satisfied: setuptools in d:\anaconda\lib\site-packages (from mlxtend) (63.4.1)
# Requirement already satisfied: scikit-learn>=1.0.2 in d:\anaconda\lib\site-packages (from mlxtend) (1.0.2)
# Requirement already satisfied: pandas>=0.24.2 in d:\anaconda\lib\site-packages (from mlxtend) (1.4.4)
# Requirement already satisfied: scipy>=1.2.1 in d:\anaconda\lib\site-packages (from mlxtend) (1.9.1)
# Requirement already satisfied: numpy>=1.16.2 in d:\anaconda\lib\site-packages (from mlxtend) (1.21.5)
# Requirement already satisfied: fonttools>=4.22.0 in d:\anaconda\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (4.25.0)
# Requirement already satisfied: pyparsing>=2.2.1 in d:\anaconda\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in d:\anaconda\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\anaconda\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.2)
# Requirement already satisfied: pillow>=6.2.0 in d:\anaconda\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (9.2.0)
# Requirement already satisfied: cycler>=0.10 in d:\anaconda\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in d:\anaconda\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in d:\anaconda\lib\site-packages (from pandas>=0.24.2->mlxtend) (2022.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in d:\anaconda\lib\site-packages (from scikit-learn>=1.0.2->mlxtend) (2.2.0)
# Requirement already satisfied: six>=1.5 in d:\anaconda\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)

# %% [markdown]
# ### One-hot encoding
#
# Sometimes it is required to transform categorical data where features might take more than two values into one-hot encoding, where each feature can take either 0 or 1 (or True/False). For example, let's consider the following set of baskets with each basket containing all the items bought during a simple trip to the supermarket. Using the following script (which uses a TransactionEncoder from mlxtend) we obtain a one-hot encoding of the data, which is required by the apriori method of mlxtend:

# %%
from mlxtend.preprocessing import TransactionEncoder

dataset = [['Milk', 'Onion', 'Nutmeg', 'Kidney Beans', 'Eggs', 'Yogurt'],
           ['Dill', 'Onion', 'Nutmeg', 'Kidney Beans', 'Eggs', 'Yogurt'],
           ['Milk', 'Apple', 'Kidney Beans', 'Eggs'],
           ['Milk', 'Unicorn', 'Corn', 'Kidney Beans', 'Yogurt'],
           ['Corn', 'Onion', 'Onion', 'Kidney Beans', 'Ice cream', 'Eggs']]

type(dataset)
# Out:
# list

# %%
te = TransactionEncoder()
te_ary = te.fit(dataset).transform(dataset)
te_ary

# %% [markdown]
# Observe that we have now a number of features being equal to the number of items in the data. Each column corresponds to a feature, while each row-column entry specifies whether the corresponding basket contains the corresponding feature or not (e.g. "Milk").

# %% [markdown]
# ### Frequent itemsets and association rules
#
# Finally we are able to run apriori on the data represented with one-hot encoding using the corresponding methods from mlxtend. Please find below the full code:

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori


dataset = [['Milk', 'Onion', 'Nutmeg', 'Kidney Beans', 'Eggs', 'Yogurt'],
           ['Dill', 'Onion', 'Nutmeg', 'Kidney Beans', 'Eggs', 'Yogurt'],
           ['Milk', 'Apple', 'Kidney Beans', 'Eggs'],
           ['Milk', 'Unicorn', 'Corn', 'Kidney Beans', 'Yogurt'],
           ['Corn', 'Onion', 'Onion', 'Kidney Beans', 'Ice cream', 'Eggs']]

te = TransactionEncoder()
te_ary = te.fit(dataset).transform(dataset)
df = pd.DataFrame(te_ary, columns=te.columns_)
df
# Out:
#    Apple   Corn   Dill   Eggs  Ice cream  Kidney Beans   Milk  Nutmeg  Onion  \
# 0  False  False  False   True      False          True   True    True   True
# 1  False  False   True   True      False          True  False    True   True
# 2   True  False  False   True      False          True   True   False  False
# 3  False   True  False  False      False          True   True   False  False
# 4  False   True  False   True       True          True  False   False   True
#
#    Unicorn  Yogurt
# 0    False    True
# 1    False    True
# 2    False   False
# 3     True    True
# 4    False   False

# %%
dataset
# Out:
# [['Milk', 'Onion', 'Nutmeg', 'Kidney Beans', 'Eggs', 'Yogurt'],
#  ['Dill', 'Onion', 'Nutmeg', 'Kidney Beans', 'Eggs', 'Yogurt'],
#  ['Milk', 'Apple', 'Kidney Beans', 'Eggs'],
#  ['Milk', 'Unicorn', 'Corn', 'Kidney Beans', 'Yogurt'],
#  ['Corn', 'Onion', 'Onion', 'Kidney Beans', 'Ice cream', 'Eggs']]

# %% [markdown]
# ### DataFrame
#
# One convenient way to load data from an input file and perform some preprocessing on it is to use panda DataFrame. A DataFrame is a "two-dimensional, size-mutable, potentially heterogeneous tabular data." It contains several tools to process and handle tabular data. Click on this <a href="https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.html">link</a> for a documentation.
#
# To use a DataFrame we need to install the "pandas" library with any of the methods we saw up to now.

# %%
frequent_itemsets = apriori(df, min_support=0.6, use_colnames=True)

frequent_itemsets
# Out:
#     support                     itemsets
# 0       0.8                       (Eggs)
# 1       1.0               (Kidney Beans)
# 2       0.6                       (Milk)
# 3       0.6                      (Onion)
# 4       0.6                     (Yogurt)
# 5       0.8         (Eggs, Kidney Beans)
# 6       0.6                (Eggs, Onion)
# 7       0.6         (Milk, Kidney Beans)
# 8       0.6        (Onion, Kidney Beans)
# 9       0.6       (Yogurt, Kidney Beans)
# 10      0.6  (Eggs, Onion, Kidney Beans)

# %%
from mlxtend.frequent_patterns import association_rules

a=association_rules(frequent_itemsets, metric="confidence", min_threshold=0.7)

a[["antecedents","consequents","support","confidence"]]
# Out:
#               antecedents            consequents  support  confidence
# 0                  (Eggs)         (Kidney Beans)      0.8        1.00
# 1          (Kidney Beans)                 (Eggs)      0.8        0.80
# 2                  (Eggs)                (Onion)      0.6        0.75
# 3                 (Onion)                 (Eggs)      0.6        1.00
# 4                  (Milk)         (Kidney Beans)      0.6        1.00
# 5                 (Onion)         (Kidney Beans)      0.6        1.00
# 6                (Yogurt)         (Kidney Beans)      0.6        1.00
# 7           (Eggs, Onion)         (Kidney Beans)      0.6        1.00
# 8    (Eggs, Kidney Beans)                (Onion)      0.6        0.75
# 9   (Onion, Kidney Beans)                 (Eggs)      0.6        1.00
# 10                 (Eggs)  (Onion, Kidney Beans)      0.6        0.75
# 11                (Onion)   (Eggs, Kidney Beans)      0.6        1.00

# %%
import pandas as pd

#read order_data.csv and create a DataFrame with that content
data = pd.read_csv(r"order_data.csv",delimiter=" ",header=None)
data
# Out:
#              0           1        2           3          4           5  \
# 0   toothpaste       brush     milk     cereals      honey       bread
# 1         milk     cereals    honey       bread     cheese       razor
# 2         milk     cereals    honey      cheese       soap     shampoo
# 3        honey       bread   butter      cheese  mouthwash  toothpaste
# 4      cereals       honey    bread      butter        gel        soap
# 5      cheesse      yogurt     milk     cereals      honey     shampoo
# 6        honey       bread   cheese       razor     butter      yogurt
# 7        honey       bread   cheese      butter       milk         NaN
# 8      cereals      butter  cookies       chips        NaN         NaN
# 9       cerals      cheese   yogurt     cookies      chips         NaN
# 10  toothpaste       brush      gel     shampoo       soap     cookies
# 11  toothpaste       brush      gel       razor  mouthwash        milk
# 12       razor     shampoo      gel        soap      bread      butter
# 13       brush     shampoo      gel  toothpaste  mouthwash       bread
# 14   mouthwash  toothpaste     soap     shampoo     cheese      yogurt
# 15       razor   mouthwash     soap      butter      bread      cheese
# 16     shampoo        soap      gel        milk      honey     cereals
# 17  toothpaste       razor      gel       brush  mouthwash     shampoo
# 18         gel       razor  shampoo        milk    cereals       bread
# 19   mouthwash  toothpaste     milk       bread    cookies         NaN
#
#           6        7       8
# 0    butter   cheese  yogurt
# 1       gel  shampoo     NaN
# 2       NaN      NaN     NaN
# 3       NaN      NaN     NaN
# 4       NaN      NaN     NaN
# 5       gel      NaN     NaN
# 6       NaN      NaN     NaN
# 7       NaN      NaN     NaN
# 8       NaN      NaN     NaN
# 9       NaN      NaN     NaN
# 10    chips      NaN     NaN
# 11  cookies      NaN     NaN
# 12      NaN      NaN     NaN
# 13   cheese      NaN     NaN
# 14      NaN      NaN     NaN
# 15      NaN      NaN     NaN
# 16      NaN      NaN     NaN
# 17      NaN      NaN     NaN
# 18  cookies      NaN     NaN
# 19      NaN      NaN     NaN

# %%
#we run apriori on the order_data.csv file

import math
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules


data = pd.read_csv(r"order_data.csv",delimiter=" ",header=None)

#preprocessing: change to one hot encoding so as to be able to use apriori from mlxtend
d=data.values.tolist()

#removing nan values
for i in range(len(d)):
    j=0
    while(True):
        if (type(d[i][j])==float and math.isnan(d[i][j])) :
            del d[i][j]
            j-=1
        j+=1
        if (j>len(d[i])-1):
            break

te = TransactionEncoder()
te_ary = te.fit(d).transform(d)
df = pd.DataFrame(te_ary, columns=te.columns_)

#computing frequent itemsets and association rules
frequent_itemsets = apriori(df, min_support=0.2, use_colnames=True)

a=association_rules(frequent_itemsets, metric="confidence", min_threshold=0.6)

#visualizing association rules results
a[["antecedents","consequents","support","confidence"]]
# Out:
#             antecedents         consequents  support  confidence
# 0              (butter)             (bread)     0.35    0.875000
# 1               (bread)            (butter)     0.35    0.636364
# 2              (cheese)             (bread)     0.35    0.700000
# 3               (bread)            (cheese)     0.35    0.636364
# 4               (honey)             (bread)     0.30    0.666667
# ..                  ...                 ...      ...         ...
# 99   (cereals, shampoo)       (milk, honey)     0.20    0.800000
# 100    (cereals, honey)     (milk, shampoo)     0.20    0.666667
# 101     (milk, shampoo)    (cereals, honey)     0.20    0.800000
# 102       (milk, honey)  (cereals, shampoo)     0.20    0.666667
# 103    (shampoo, honey)     (cereals, milk)     0.20    1.000000
#
# [104 rows x 4 columns]

# %%
type(a["antecedents"][99]) #prints frozenset
# Out:
# frozenset

# %%
#frozenset is very similar to a set in Python with the main difference that cannot be changed.
#so we can check if a rule contains shampoo and honey as follows
i=99
if ("shampoo" in a["antecedents"][i] and "honey" in a["consequents"][i] ):
    print ("The "+str(i)+" rule talks about shampoo and honey:" )
else:
    print ("The "+str(i)+"th rule does not talk about shampoo and honey:" )
# Out:
# The 99 rule talks about shampoo and honey:

# %%
import math
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules


data = pd.read_csv(r"mammographic_masses.csv",delimiter=",",header=0)

#preprocessing: change to one hot encoding so as to be able to use apriori from mlxtend
d=data.values.tolist()

d
# Out:
# [['5', '67', '3', '5', '3', 1],
#  ['4', '43', '1', '1', '?', 1],
#  ['5', '58', '4', '5', '3', 1],
#  ['4', '28', '1', '1', '3', 0],
#  ['5', '74', '1', '5', '?', 1],
#  ['4', '65', '1', '?', '3', 0],
#  ['4', '70', '?', '?', '3', 0],
#  ['5', '42', '1', '?', '3', 0],
#  ['5', '57', '1', '5', '3', 1],
#  ['5', '60', '?', '5', '1', 1],
#  ['5', '76', '1', '4', '3', 1],
#  ['3', '42', '2', '1', '3', 1],
#  ['4', '64', '1', '?', '3', 0],
#  ['4', '36', '3', '1', '2', 0],
#  ['4', '60', '2', '1', '2', 0],
#  ['4', '54', '1', '1', '3', 0],
#  ['3', '52', '3', '4', '3', 0],
#  ['4', '59', '2', '1', '3', 1],
#  ['4', '54', '1', '1', '3', 1],
#  ['4', '40', '1', '?', '?', 0],
#  ['?', '66', '?', '?', '1', 1],
#  ['5', '56', '4', '3', '1', 1],
#  ['4', '43', '1', '?', '?', 0],
#  ['5', '42', '4', '4', '3', 1],
#  ['4', '59', '2', '4', '3', 1],
#  ['5', '75', '4', '5', '3', 1],
#  ['2', '66', '1', '1', '?', 0],
#  ['5', '63', '3', '?', '3', 0],
#  ['5', '45', '4', '5', '3', 1],
#  ['5', '55', '4', '4', '3', 0],
#  ['4', '46', '1', '5', '2', 0],
#  ['5', '54', '4', '4', '3', 1],
#  ['5', '57', '4', '4', '3', 1],
#  ['4', '39', '1', '1', '2', 0],
#  ['4', '81', '1', '1', '3', 0],
#  ['4', '77', '3', '?', '?', 0],
#  ['4', '60', '2', '1', '3', 0],
#  ['5', '67', '3', '4', '2', 1],
#  ['4', '48', '4', '5', '?', 1],
#  ['4', '55', '3', '4', '2', 0],
#  ['4', '59', '2', '1', '?', 0],
#  ['4', '78', '1', '1', '1', 0],
#  ['4', '50', '1', '1', '3', 0],
#  ['4', '61', '2', '1', '?', 0],
#  ['5', '62', '3', '5', '2', 1],
#  ['5', '44', '2', '4', '?', 1],
#  ['5', '64', '4', '5', '3', 1],
#  ['4', '23', '1', '1', '?', 0],
#  ['2', '42', '?', '?', '4', 0],
#  ['5', '67', '4', '5', '3', 1],
#  ['4', '74', '2', '1', '2', 0],
#  ['5', '80', '3', '5', '3', 1],
#  ['4', '23', '1', '1', '?', 0],
#  ['4', '63', '2', '1', '?', 0],
#  ['4', '53', '?', '5', '3', 1],
#  ['4', '43', '3', '4', '?', 0],
#  ['4', '49', '2', '1', '1', 0],
#  ['5', '51', '2', '4', '?', 0],
#  ['4', '45', '2', '1', '?', 0],
#  ['5', '59', '2', '?', '?', 1],
#  ['5', '52', '4', '3', '3', 1],
#  ['5', '60', '4', '3', '3', 1],
#  ['4', '57', '2', '5', '3', 0],
#  ['3', '57', '2', '1', '?', 0],
#  ['5', '74', '4', '4', '3', 1],
#  ['4', '25', '2', '1', '?', 0],
#  ['4', '49', '1', '1', '3', 0],
#  ['5', '72', '4', '3', '?', 1],
#  ['4', '45', '2', '1', '3', 0],
#  ['4', '64', '2', '1', '3', 0],
#  ['4', '73', '2', '1', '2', 0],
#  ['5', '68', '4', '3', '3', 1],
#  ['5', '52', '4', '5', '3', 0],
#  ['5', '66', '4', '4', '3', 1],
#  ['5', '70', '?', '4', '?', 1],
#  ['4', '25', '1', '1', '3', 0],
#  ['5', '74', '1', '1', '2', 1],
#  ['4', '64', '1', '1', '3', 0],
#  ['5', '60', '4', '3', '2', 1],
#  ['5', '67', '2', '4', '1', 0],
#  ['4', '67', '4', '5', '3', 0],
#  ['5', '44', '4', '4', '2', 1],
#  ['3', '68', '1', '1', '3', 1],
#  ['4', '57', '?', '4', '1', 0],
#  ['5', '51', '4', '?', '?', 1],
#  ['4', '33', '1', '?', '?', 0],
#  ['5', '58', '4', '4', '3', 1],
#  ['5', '36', '1', '?', '?', 0],
#  ['4', '63', '1', '1', '?', 0],
#  ['5', '62', '1', '5', '3', 1],
#  ['4', '73', '3', '4', '3', 1],
#  ['4', '80', '4', '4', '3', 1],
#  ['4', '67', '1', '1', '?', 0],
#  ['5', '59', '2', '1', '3', 1],
#  ['5', '60', '1', '?', '3', 0],
#  ['5', '54', '4', '4', '3', 1],
#  ['4', '40', '1', '1', '?', 0],
#  ['4', '47', '2', '1', '?', 0],
#  ['5', '62', '4', '4', '3', 0],
#  ['4', '33', '2', '1', '3', 0],
#  ['5', '59', '2', '?', '?', 0],
#  ['4', '65', '2', '?', '?', 0],
#  ['4', '58', '4', '4', '?', 0],
#  ['4', '29', '2', '?', '?', 0],
#  ['4', '58', '1', '1', '?', 0],
#  ['4', '54', '1', '1', '?', 0],
#  ['4', '44', '1', '1', '?', 1],
#  ['3', '34', '2', '1', '?', 0],
#  ['4', '57', '1', '1', '3', 0],
#  ['5', '33', '4', '4', '?', 1],
#  ['4', '45', '4', '4', '3', 0],
#  ['5', '71', '4', '4', '3', 1],
#  ['5', '59', '4', '4', '2', 0],
#  ['4', '56', '2', '1', '?', 0],
#  ['4', '40', '3', '4', '?', 0],
#  ['4', '56', '1', '1', '3', 0],
#  ['4', '45', '2', '1', '?', 0],
#  ['4', '57', '2', '1', '2', 0],
#  ['5', '55', '3', '4', '3', 1],
#  ['5', '84', '4', '5', '3', 0],
#  ['5', '51', '4', '4', '3', 1],
#  ['4', '43', '1', '1', '?', 0],
#  ['4', '24', '2', '1', '2', 0],
#  ['4', '66', '1', '1', '3', 0],
#  ['5', '33', '4', '4', '3', 0],
#  ['4', '59', '4', '3', '2', 0],
#  ['4', '76', '2', '3', '?', 0],
#  ['4', '40', '1', '1', '?', 0],
#  ['4', '52', '?', '4', '?', 0],
#  ['5', '40', '4', '5', '3', 1],
#  ['5', '67', '4', '4', '3', 1],
#  ['5', '75', '4', '3', '3', 1],
#  ['5', '86', '4', '4', '3', 0],
#  ['4', '60', '2', '?', '?', 0],
#  ['5', '66', '4', '4', '3', 1],
#  ['5', '46', '4', '5', '3', 1],
#  ['4', '59', '4', '4', '3', 1],
#  ['5', '65', '4', '4', '3', 1],
#  ['4', '53', '1', '1', '3', 0],
#  ['5', '67', '3', '5', '3', 1],
#  ['5', '80', '4', '5', '3', 1],
#  ['4', '55', '2', '1', '3', 0],
#  ['4', '48', '1', '1', '?', 0],
#  ['4', '47', '1', '1', '2', 0],
#  ['4', '50', '2', '1', '?', 0],
#  ['5', '62', '4', '5', '3', 1],
#  ['5', '63', '4', '4', '3', 1],
#  ['4', '63', '4', '?', '3', 1],
#  ['4', '71', '4', '4', '3', 1],
#  ['4', '41', '1', '1', '3', 0],
#  ['5', '57', '4', '4', '4', 1],
#  ['5', '71', '4', '4', '4', 1],
#  ['4', '66', '1', '1', '3', 0],
#  ['4', '47', '2', '4', '2', 0],
#  ['3', '34', '4', '4', '3', 0],
#  ['4', '59', '3', '4', '3', 0],
#  ['5', '55', '2', '?', '?', 1],
#  ['4', '51', '?', '?', '3', 0],
#  ['4', '62', '2', '1', '?', 0],
#  ['4', '58', '4', '?', '3', 1],
#  ['5', '67', '4', '4', '3', 1],
#  ['4', '41', '2', '1', '3', 0],
#  ['4', '23', '3', '1', '3', 0],
#  ['4', '53', '?', '4', '3', 0],
#  ['4', '42', '2', '1', '3', 0],
#  ['5', '87', '4', '5', '3', 1],
#  ['4', '68', '1', '1', '3', 1],
#  ['4', '64', '1', '1', '3', 0],
#  ['5', '54', '3', '5', '3', 1],
#  ['5', '86', '4', '5', '3', 1],
#  ['4', '21', '2', '1', '3', 0],
#  ['4', '39', '1', '1', '?', 0],
#  ['4', '53', '4', '4', '3', 0],
#  ['4', '44', '4', '4', '3', 0],
#  ['4', '54', '1', '1', '3', 0],
#  ['5', '63', '4', '5', '3', 1],
#  ['4', '62', '2', '1', '?', 0],
#  ['4', '45', '2', '1', '2', 0],
#  ['5', '71', '4', '5', '3', 0],
#  ['5', '49', '4', '4', '3', 1],
#  ['4', '49', '4', '4', '3', 0],
#  ['5', '66', '4', '4', '4', 0],
#  ['4', '19', '1', '1', '3', 0],
#  ['4', '35', '1', '1', '2', 0],
#  ['4', '71', '3', '3', '?', 1],
#  ['5', '74', '4', '5', '3', 1],
#  ['5', '37', '4', '4', '3', 1],
#  ['4', '67', '1', '?', '3', 0],
#  ['5', '81', '3', '4', '3', 1],
#  ['5', '59', '4', '4', '3', 1],
#  ['4', '34', '1', '1', '3', 0],
#  ['5', '79', '4', '3', '3', 1],
#  ['5', '60', '3', '1', '3', 0],
#  ['4', '41', '1', '1', '3', 1],
#  ['4', '50', '1', '1', '3', 0],
#  ['5', '85', '4', '4', '3', 1],
#  ['4', '46', '1', '1', '3', 0],
#  ['5', '66', '4', '4', '3', 1],
#  ['4', '73', '3', '1', '2', 0],
#  ['4', '55', '1', '1', '3', 0],
#  ['4', '49', '2', '1', '3', 0],
#  ['3', '49', '4', '4', '3', 0],
#  ['4', '51', '4', '5', '3', 1],
#  ['2', '48', '4', '4', '3', 0],
#  ['4', '58', '4', '5', '3', 0],
#  ['5', '72', '4', '5', '3', 1],
#  ['4', '46', '2', '3', '3', 0],
#  ['4', '43', '4', '3', '3', 1],
#  ['?', '52', '4', '4', '3', 0],
#  ['4', '66', '2', '1', '?', 0],
#  ['4', '46', '1', '1', '1', 0],
#  ['4', '69', '3', '1', '3', 0],
#  ['2', '59', '1', '1', '?', 1],
#  ['5', '43', '2', '1', '3', 1],
#  ['5', '76', '4', '5', '3', 1],
#  ['4', '46', '1', '1', '3', 0],
#  ['4', '59', '2', '4', '3', 0],
#  ['4', '57', '1', '1', '3', 0],
#  ['5', '43', '4', '5', '?', 0],
#  ['3', '45', '2', '1', '3', 0],
#  ['3', '43', '2', '1', '3', 0],
#  ['4', '45', '2', '1', '3', 0],
#  ['5', '57', '4', '5', '3', 1],
#  ['5', '79', '4', '4', '3', 1],
#  ['5', '54', '2', '1', '3', 1],
#  ['4', '40', '3', '4', '3', 0],
#  ['5', '63', '4', '4', '3', 1],
#  ['2', '55', '1', '?', '1', 0],
#  ['4', '52', '2', '1', '3', 0],
#  ['4', '38', '1', '1', '3', 0],
#  ['3', '72', '4', '3', '3', 0],
#  ['5', '80', '4', '3', '3', 1],
#  ['5', '76', '4', '3', '3', 1],
#  ['4', '62', '3', '1', '3', 0],
#  ['5', '64', '4', '5', '3', 1],
#  ['5', '42', '4', '5', '3', 0],
#  ['3', '60', '?', '3', '1', 0],
#  ['4', '64', '4', '5', '3', 0],
#  ['4', '63', '4', '4', '3', 1],
#  ['4', '24', '2', '1', '2', 0],
#  ['5', '72', '4', '4', '3', 1],
#  ['4', '63', '2', '1', '3', 0],
#  ['4', '46', '1', '1', '3', 0],
#  ['3', '33', '1', '1', '3', 0],
#  ['5', '76', '4', '4', '3', 1],
#  ['4', '36', '2', '3', '3', 0],
#  ['4', '40', '2', '1', '3', 0],
#  ['5', '58', '1', '5', '3', 1],
#  ['4', '43', '2', '1', '3', 0],
#  ['3', '42', '1', '1', '3', 0],
#  ['4', '32', '1', '1', '3', 0],
#  ['5', '57', '4', '4', '2', 1],
#  ['4', '37', '1', '1', '3', 0],
#  ['4', '70', '4', '4', '3', 1],
#  ['5', '56', '4', '2', '3', 1],
#  ['3', '76', '?', '3', '2', 0],
#  ['5', '73', '4', '4', '3', 1],
#  ['5', '77', '4', '5', '3', 1],
#  ['5', '67', '4', '4', '1', 1],
#  ['5', '71', '4', '3', '3', 1],
#  ['5', '65', '4', '4', '3', 1],
#  ['4', '43', '1', '1', '3', 0],
#  ['4', '40', '2', '1', '?', 0],
#  ['4', '49', '2', '1', '3', 0],
#  ['5', '76', '4', '2', '3', 1],
#  ['4', '55', '4', '4', '3', 0],
#  ['5', '72', '4', '5', '3', 1],
#  ['3', '53', '4', '3', '3', 0],
#  ['5', '75', '4', '4', '3', 1],
#  ['5', '61', '4', '5', '3', 1],
#  ['5', '67', '4', '4', '3', 1],
#  ['5', '55', '4', '2', '3', 1],
#  ['5', '66', '4', '4', '3', 1],
#  ['2', '76', '1', '1', '2', 0],
#  ['4', '57', '4', '4', '3', 1],
#  ['5', '71', '3', '1', '3', 0],
#  ['5', '70', '4', '5', '3', 1],
#  ['4', '35', '4', '2', '?', 0],
#  ['5', '79', '1', '?', '3', 1],
#  ['4', '63', '2', '1', '3', 0],
#  ['5', '40', '1', '4', '3', 1],
#  ['4', '41', '1', '1', '3', 0],
#  ['4', '47', '2', '1', '2', 0],
#  ['4', '68', '1', '1', '3', 1],
#  ['4', '64', '4', '3', '3', 1],
#  ['4', '65', '4', '4', '?', 1],
#  ['4', '73', '4', '3', '3', 0],
#  ['4', '39', '4', '3', '3', 0],
#  ['5', '55', '4', '5', '4', 1],
#  ['5', '53', '3', '4', '4', 0],
#  ['5', '66', '4', '4', '3', 1],
#  ['4', '43', '3', '1', '2', 0],
#  ['5', '44', '4', '5', '3', 1],
#  ['4', '77', '4', '4', '3', 1],
#  ['4', '62', '2', '4', '3', 0],
#  ['5', '80', '4', '4', '3', 1],
#  ['4', '33', '4', '4', '3', 0],
#  ['4', '50', '4', '5', '3', 1],
#  ['4', '71', '1', '?', '3', 0],
#  ['5', '46', '4', '4', '3', 1],
#  ['5', '49', '4', '5', '3', 1],
#  ['4', '53', '1', '1', '3', 0],
#  ['3', '46', '2', '1', '2', 0],
#  ['4', '57', '1', '1', '3', 0],
#  ['4', '54', '3', '1', '3', 0],
#  ['4', '54', '1', '?', '?', 0],
#  ['2', '49', '2', '1', '2', 0],
#  ['4', '47', '3', '1', '3', 0],
#  ['4', '40', '1', '1', '3', 0],
#  ['4', '45', '1', '1', '3', 0],
#  ['4', '50', '4', '5', '3', 1],
#  ['5', '54', '4', '4', '3', 1],
#  ['4', '67', '4', '1', '3', 1],
#  ['4', '77', '4', '4', '3', 1],
#  ['4', '66', '4', '3', '3', 0],
#  ['4', '71', '2', '?', '3', 1],
#  ['4', '36', '2', '3', '3', 0],
#  ['4', '69', '4', '4', '3', 0],
#  ['4', '48', '1', '1', '3', 0],
#  ['4', '64', '4', '4', '3', 1],
#  ['4', '71', '4', '2', '3', 1],
#  ['5', '60', '4', '3', '3', 1],
#  ['4', '24', '1', '1', '3', 0],
#  ['5', '34', '4', '5', '2', 1],
#  ['4', '79', '1', '1', '2', 0],
#  ['4', '45', '1', '1', '3', 0],
#  ['4', '37', '2', '1', '2', 0],
#  ['4', '42', '1', '1', '2', 0],
#  ['4', '72', '4', '4', '3', 1],
#  ['5', '60', '4', '5', '3', 1],
#  ['5', '85', '3', '5', '3', 1],
#  ['4', '51', '1', '1', '3', 0],
#  ['5', '54', '4', '5', '3', 1],
#  ['5', '55', '4', '3', '3', 1],
#  ['4', '64', '4', '4', '3', 0],
#  ['5', '67', '4', '5', '3', 1],
#  ['5', '75', '4', '3', '3', 1],
#  ['5', '87', '4', '4', '3', 1],
#  ['4', '46', '4', '4', '3', 1],
#  ['4', '59', '2', '1', '?', 0],
#  ['5', '46', '4', '3', '3', 1],
#  ['5', '61', '1', '1', '3', 1],
#  ['4', '44', '1', '4', '3', 0],
#  ['4', '32', '1', '1', '3', 0],
#  ['4', '62', '1', '1', '3', 0],
#  ['5', '59', '4', '5', '3', 1],
#  ['4', '61', '4', '1', '3', 0],
#  ['5', '78', '4', '4', '3', 1],
#  ['5', '42', '4', '5', '3', 0],
#  ['4', '45', '1', '2', '3', 0],
#  ['5', '34', '2', '1', '3', 1],
#  ['5', '39', '4', '3', '?', 1],
#  ['4', '27', '3', '1', '3', 0],
#  ['4', '43', '1', '1', '3', 0],
#  ['5', '83', '4', '4', '3', 1],
#  ['4', '36', '2', '1', '3', 0],
#  ['4', '37', '2', '1', '3', 0],
#  ['4', '56', '3', '1', '3', 1],
#  ['5', '55', '4', '4', '3', 1],
#  ['5', '46', '3', '?', '3', 0],
#  ['4', '88', '4', '4', '3', 1],
#  ['5', '71', '4', '4', '3', 1],
#  ['4', '41', '2', '1', '3', 0],
#  ['5', '49', '4', '4', '3', 1],
#  ['3', '51', '1', '1', '4', 0],
#  ['4', '39', '1', '3', '3', 0],
#  ['4', '46', '2', '1', '3', 0],
#  ['5', '52', '4', '4', '3', 1],
#  ['5', '58', '4', '4', '3', 1],
#  ['4', '67', '4', '5', '3', 1],
#  ['5', '80', '4', '4', '3', 1],
#  ['3', '46', '1', '?', '?', 0],
#  ['3', '43', '1', '?', '?', 0],
#  ['4', '45', '1', '1', '3', 0],
#  ['5', '68', '4', '4', '3', 1],
#  ['4', '54', '4', '4', '?', 1],
#  ['4', '44', '2', '3', '3', 0],
#  ['5', '74', '4', '3', '3', 1],
#  ['5', '55', '4', '5', '3', 0],
#  ['4', '49', '4', '4', '3', 1],
#  ['4', '49', '1', '1', '3', 0],
#  ['5', '50', '4', '3', '3', 1],
#  ['5', '52', '3', '5', '3', 1],
#  ['4', '45', '1', '1', '3', 0],
#  ['4', '66', '1', '1', '3', 0],
#  ['4', '68', '4', '4', '3', 1],
#  ['4', '72', '2', '1', '3', 0],
#  ['5', '64', '?', '?', '3', 0],
#  ['2', '49', '?', '3', '3', 0],
#  ['3', '44', '?', '4', '3', 0],
#  ['5', '74', '4', '4', '3', 1],
#  ['5', '58', '4', '4', '3', 1],
#  ['4', '77', '2', '3', '3', 0],
#  ['4', '49', '3', '1', '3', 0],
#  ['4', '34', '?', '?', '4', 0],
#  ['5', '60', '4', '3', '3', 1],
#  ['5', '69', '4', '3', '3', 1],
#  ['4', '53', '2', '1', '3', 0],
#  ['3', '46', '3', '4', '3', 0],
#  ['5', '74', '4', '4', '3', 1],
#  ['4', '58', '1', '1', '3', 0],
#  ['5', '68', '4', '4', '3', 1],
#  ['5', '46', '4', '3', '3', 0],
#  ['5', '61', '2', '4', '3', 1],
#  ['5', '70', '4', '3', '3', 1],
#  ['5', '37', '4', '4', '3', 1],
#  ['3', '65', '4', '5', '3', 1],
#  ['4', '67', '4', '4', '3', 0],
#  ['5', '69', '3', '4', '3', 0],
#  ['5', '76', '4', '4', '3', 1],
#  ['4', '65', '4', '3', '3', 0],
#  ['5', '72', '4', '2', '3', 1],
#  ['4', '62', '4', '2', '3', 0],
#  ['5', '42', '4', '4', '3', 1],
#  ['5', '66', '4', '3', '3', 1],
#  ['5', '48', '4', '4', '3', 1],
#  ['4', '35', '1', '1', '3', 0],
#  ['5', '60', '4', '4', '3', 1],
#  ['5', '67', '4', '2', '3', 1],
#  ['5', '78', '4', '4', '3', 1],
#  ['4', '66', '1', '1', '3', 1],
#  ['4', '26', '1', '1', '?', 0],
#  ['4', '48', '1', '1', '3', 0],
#  ['4', '31', '1', '1', '3', 0],
#  ['5', '43', '4', '3', '3', 1],
#  ['5', '72', '2', '4', '3', 0],
#  ['5', '66', '1', '1', '3', 1],
#  ['4', '56', '4', '4', '3', 0],
#  ['5', '58', '4', '5', '3', 1],
#  ['5', '33', '2', '4', '3', 1],
#  ['4', '37', '1', '1', '3', 0],
#  ['5', '36', '4', '3', '3', 1],
#  ['4', '39', '2', '3', '3', 0],
#  ['4', '39', '4', '4', '3', 1],
#  ['5', '83', '4', '4', '3', 1],
#  ['4', '68', '4', '5', '3', 1],
#  ['5', '63', '3', '4', '3', 1],
#  ['5', '78', '4', '4', '3', 1],
#  ['4', '38', '2', '3', '3', 0],
#  ['5', '46', '4', '3', '3', 1],
#  ['5', '60', '4', '4', '3', 1],
#  ['5', '56', '2', '3', '3', 1],
#  ['4', '33', '1', '1', '3', 0],
#  ['4', '?', '4', '5', '3', 1],
#  ['4', '69', '1', '5', '3', 1],
#  ['5', '66', '1', '4', '3', 1],
#  ['4', '72', '1', '3', '3', 0],
#  ['4', '29', '1', '1', '3', 0],
#  ['5', '54', '4', '5', '3', 1],
#  ['5', '80', '4', '4', '3', 1],
#  ['5', '68', '4', '3', '3', 1],
#  ['4', '35', '2', '1', '3', 0],
#  ['4', '57', '3', '?', '3', 0],
#  ['5', '?', '4', '4', '3', 1],
#  ['4', '50', '1', '1', '3', 0],
#  ['4', '32', '4', '3', '3', 0],
#  ['0', '69', '4', '5', '3', 1],
#  ['4', '71', '4', '5', '3', 1],
#  ['5', '87', '4', '5', '3', 1],
#  ['3', '40', '2', '?', '3', 0],
#  ['4', '31', '1', '1', '?', 0],
#  ['4', '64', '1', '1', '3', 0],
#  ['5', '55', '4', '5', '3', 1],
#  ['4', '18', '1', '1', '3', 0],
#  ['3', '50', '2', '1', '?', 0],
#  ['4', '53', '1', '1', '3', 0],
#  ['5', '84', '4', '5', '3', 1],
#  ['5', '80', '4', '3', '3', 1],
#  ['4', '32', '1', '1', '3', 0],
#  ['5', '77', '3', '4', '3', 1],
#  ['4', '38', '1', '1', '3', 0],
#  ['5', '54', '4', '5', '3', 1],
#  ['4', '63', '1', '1', '3', 0],
#  ['4', '61', '1', '1', '3', 0],
#  ['4', '52', '1', '1', '3', 0],
#  ['4', '36', '1', '1', '3', 0],
#  ['4', '41', '?', '?', '3', 0],
#  ['4', '59', '1', '1', '3', 0],
#  ['5', '51', '4', '4', '2', 1],
#  ['4', '36', '1', '1', '3', 0],
#  ['5', '40', '4', '3', '3', 1],
#  ['4', '49', '1', '1', '3', 0],
#  ['4', '37', '2', '3', '3', 0],
#  ['4', '46', '1', '1', '3', 0],
#  ['4', '63', '1', '1', '3', 0],
#  ['4', '28', '2', '1', '3', 0],
#  ['4', '47', '2', '1', '3', 0],
#  ['4', '42', '2', '1', '3', 1],
#  ['5', '44', '4', '5', '3', 1],
#  ['4', '49', '4', '4', '3', 0],
#  ['5', '47', '4', '5', '3', 1],
#  ['5', '52', '4', '5', '3', 1],
#  ['4', '53', '1', '1', '3', 1],
#  ['5', '83', '3', '3', '3', 1],
#  ['4', '50', '4', '4', '?', 1],
#  ['5', '63', '4', '4', '3', 1],
#  ['4', '82', '?', '5', '3', 1],
#  ['4', '54', '1', '1', '3', 0],
#  ['4', '50', '4', '4', '3', 0],
#  ['5', '80', '4', '5', '3', 1],
#  ['5', '45', '2', '4', '3', 0],
#  ['5', '59', '4', '4', '?', 1],
#  ['4', '28', '2', '1', '3', 0],
#  ['4', '31', '1', '1', '3', 0],
#  ['4', '41', '2', '1', '3', 0],
#  ['4', '21', '3', '1', '3', 0],
#  ['5', '44', '3', '4', '3', 1],
#  ['5', '49', '4', '4', '3', 1],
#  ['5', '71', '4', '5', '3', 1],
#  ['5', '75', '4', '5', '3', 1],
#  ['4', '38', '2', '1', '3', 0],
#  ['4', '60', '1', '3', '3', 0],
#  ['5', '87', '4', '5', '3', 1],
#  ['4', '70', '4', '4', '3', 1],
#  ['5', '55', '4', '5', '3', 1],
#  ['3', '21', '1', '1', '3', 0],
#  ['4', '50', '1', '1', '3', 0],
#  ['5', '76', '4', '5', '3', 1],
#  ['4', '23', '1', '1', '3', 0],
#  ['3', '68', '?', '?', '3', 0],
#  ['4', '62', '4', '?', '3', 1],
#  ['5', '65', '1', '?', '3', 1],
#  ['5', '73', '4', '5', '3', 1],
#  ['4', '38', '2', '3', '3', 0],
#  ['2', '57', '1', '1', '3', 0],
#  ['5', '65', '4', '5', '3', 1],
#  ['5', '67', '2', '4', '3', 1],
#  ['5', '61', '2', '4', '3', 1],
#  ['5', '56', '4', '4', '3', 0],
#  ['5', '71', '2', '4', '3', 1],
#  ['4', '49', '2', '2', '3', 0],
#  ['4', '55', '?', '?', '3', 0],
#  ['4', '44', '2', '1', '3', 0],
#  ['0', '58', '4', '4', '3', 0],
#  ['4', '27', '2', '1', '3', 0],
#  ['5', '73', '4', '5', '3', 1],
#  ['4', '34', '2', '1', '3', 0],
#  ['5', '63', '?', '4', '3', 1],
#  ['4', '50', '2', '1', '3', 1],
#  ['4', '62', '2', '1', '3', 0],
#  ['3', '21', '3', '1', '3', 0],
#  ['4', '49', '2', '?', '3', 0],
#  ['4', '36', '3', '1', '3', 0],
#  ['4', '45', '2', '1', '3', 1],
#  ['5', '67', '4', '5', '3', 1],
#  ['4', '21', '1', '1', '3', 0],
#  ['4', '57', '2', '1', '3', 0],
#  ['5', '66', '4', '5', '3', 1],
#  ['4', '71', '4', '4', '3', 1],
#  ['5', '69', '3', '4', '3', 1],
#  ['6', '80', '4', '5', '3', 1],
#  ['3', '27', '2', '1', '3', 0],
#  ['4', '38', '2', '1', '3', 0],
#  ['4', '23', '2', '1', '3', 0],
#  ['5', '70', '?', '5', '3', 1],
#  ['4', '46', '4', '3', '3', 0],
#  ['4', '61', '2', '3', '3', 0],
#  ['5', '65', '4', '5', '3', 1],
#  ['4', '60', '4', '3', '3', 0],
#  ['5', '83', '4', '5', '3', 1],
#  ['5', '40', '4', '4', '3', 1],
#  ['2', '59', '?', '4', '3', 0],
#  ['4', '53', '3', '4', '3', 0],
#  ['4', '76', '4', '4', '3', 0],
#  ['5', '79', '1', '4', '3', 1],
#  ['5', '38', '2', '4', '3', 1],
#  ['4', '61', '3', '4', '3', 0],
#  ['4', '56', '2', '1', '3', 0],
#  ['4', '44', '2', '1', '3', 0],
#  ['4', '64', '3', '4', '?', 1],
#  ['4', '66', '3', '3', '3', 0],
#  ['4', '50', '3', '3', '3', 0],
#  ['4', '46', '1', '1', '3', 0],
#  ['4', '39', '1', '1', '3', 0],
#  ['4', '60', '3', '?', '?', 0],
#  ['5', '55', '4', '5', '3', 1],
#  ['4', '40', '2', '1', '3', 0],
#  ['4', '26', '1', '1', '3', 0],
#  ['5', '84', '3', '2', '3', 1],
#  ['4', '41', '2', '2', '3', 0],
#  ['4', '63', '1', '1', '3', 0],
#  ['2', '65', '?', '1', '2', 0],
#  ['4', '49', '1', '1', '3', 0],
#  ['4', '56', '2', '2', '3', 1],
#  ['5', '65', '4', '4', '3', 0],
#  ['4', '54', '1', '1', '3', 0],
#  ['4', '36', '1', '1', '3', 0],
#  ['5', '49', '4', '4', '3', 0],
#  ['4', '59', '4', '4', '3', 1],
#  ['5', '75', '4', '4', '3', 1],
#  ['5', '59', '4', '2', '3', 0],
#  ['5', '59', '4', '4', '3', 1],
#  ['4', '28', '4', '4', '3', 1],
#  ['5', '53', '4', '5', '3', 0],
#  ['5', '57', '4', '4', '3', 0],
#  ['5', '77', '4', '3', '4', 0],
#  ['5', '85', '4', '3', '3', 1],
#  ['4', '59', '4', '4', '3', 0],
#  ['5', '59', '1', '5', '3', 1],
#  ['4', '65', '3', '3', '3', 1],
#  ['4', '54', '2', '1', '3', 0],
#  ['5', '46', '4', '5', '3', 1],
#  ['4', '63', '4', '4', '3', 1],
#  ['4', '53', '1', '1', '3', 1],
#  ['4', '56', '1', '1', '3', 0],
#  ['5', '66', '4', '4', '3', 1],
#  ['5', '66', '4', '5', '3', 1],
#  ['4', '55', '1', '1', '3', 0],
#  ['4', '44', '1', '1', '3', 0],
#  ['5', '86', '3', '4', '3', 1],
#  ['5', '47', '4', '5', '3', 1],
#  ['5', '59', '4', '5', '3', 1],
#  ['5', '66', '4', '5', '3', 0],
#  ['5', '61', '4', '3', '3', 1],
#  ['3', '46', '?', '5', '?', 1],
#  ['4', '69', '1', '1', '3', 0],
#  ['5', '93', '1', '5', '3', 1],
#  ['4', '39', '1', '3', '3', 0],
#  ['5', '44', '4', '5', '3', 1],
#  ['4', '45', '2', '2', '3', 0],
#  ['4', '51', '3', '4', '3', 0],
#  ['4', '56', '2', '4', '3', 0],
#  ['4', '66', '4', '4', '3', 0],
#  ['5', '61', '4', '5', '3', 1],
#  ['4', '64', '3', '3', '3', 1],
#  ['5', '57', '2', '4', '3', 0],
#  ['5', '79', '4', '4', '3', 1],
#  ['4', '57', '2', '1', '?', 0],
#  ['4', '44', '4', '1', '1', 0],
#  ['4', '31', '2', '1', '3', 0],
#  ['4', '63', '4', '4', '3', 0],
#  ['4', '64', '1', '1', '3', 0],
#  ['5', '47', '4', '5', '3', 0],
#  ['5', '68', '4', '5', '3', 1],
#  ['4', '30', '1', '1', '3', 0],
#  ['5', '43', '4', '5', '3', 1],
#  ['4', '56', '1', '1', '3', 0],
#  ['4', '46', '2', '1', '3', 0],
#  ['4', '67', '2', '1', '3', 0],
#  ['5', '52', '4', '5', '3', 1],
#  ['4', '67', '4', '4', '3', 1],
#  ['4', '47', '2', '1', '3', 0],
#  ['5', '58', '4', '5', '3', 1],
#  ['4', '28', '2', '1', '3', 0],
#  ['4', '43', '1', '1', '3', 0],
#  ['4', '57', '2', '4', '3', 0],
#  ['5', '68', '4', '5', '3', 1],
#  ['4', '64', '2', '4', '3', 0],
#  ['4', '64', '2', '4', '3', 0],
#  ['5', '62', '4', '4', '3', 1],
#  ['4', '38', '4', '1', '3', 0],
#  ['5', '68', '4', '4', '3', 1],
#  ['4', '41', '2', '1', '3', 0],
#  ['4', '35', '2', '1', '3', 1],
#  ['4', '68', '2', '1', '3', 0],
#  ['5', '55', '4', '4', '3', 1],
#  ['5', '67', '4', '4', '3', 1],
#  ['4', '51', '4', '3', '3', 0],
#  ['2', '40', '1', '1', '3', 0],
#  ['5', '73', '4', '4', '3', 1],
#  ['4', '58', '?', '4', '3', 1],
#  ['4', '51', '?', '4', '3', 0],
#  ['3', '50', '?', '?', '3', 1],
#  ['5', '59', '4', '3', '3', 1],
#  ['6', '60', '3', '5', '3', 1],
#  ['4', '27', '2', '1', '?', 0],
#  ['5', '54', '4', '3', '3', 0],
#  ['4', '56', '1', '1', '3', 0],
#  ['5', '53', '4', '5', '3', 1],
#  ['4', '54', '2', '4', '3', 0],
#  ['5', '79', '1', '4', '3', 1],
#  ['5', '67', '4', '3', '3', 1],
#  ['5', '64', '3', '3', '3', 1],
#  ['4', '70', '1', '2', '3', 1],
#  ['5', '55', '4', '3', '3', 1],
#  ['5', '65', '3', '3', '3', 1],
#  ['5', '45', '4', '2', '3', 1],
#  ['4', '57', '4', '4', '?', 1],
#  ['5', '49', '1', '1', '3', 1],
#  ['4', '24', '2', '1', '3', 0],
#  ['4', '52', '1', '1', '3', 0],
#  ['4', '50', '2', '1', '3', 0],
#  ['4', '35', '1', '1', '3', 0],
#  ['5', '?', '3', '3', '3', 1],
#  ['5', '64', '4', '3', '3', 1],
#  ['5', '40', '4', '1', '1', 1],
#  ['5', '66', '4', '4', '3', 1],
#  ['4', '64', '4', '4', '3', 1],
#  ['5', '52', '4', '3', '3', 1],
#  ['5', '43', '1', '4', '3', 1],
#  ['4', '56', '4', '4', '3', 0],
#  ['4', '72', '3', '?', '3', 0],
#  ['6', '51', '4', '4', '3', 1],
#  ['4', '79', '4', '4', '3', 1],
#  ['4', '22', '2', '1', '3', 0],
#  ['4', '73', '2', '1', '3', 0],
#  ['4', '53', '3', '4', '3', 0],
#  ['4', '59', '2', '1', '3', 1],
#  ['4', '46', '4', '4', '2', 0],
#  ['5', '66', '4', '4', '3', 1],
#  ['4', '50', '4', '3', '3', 1],
#  ['4', '58', '1', '1', '3', 1],
#  ['4', '55', '1', '1', '3', 0],
#  ['4', '62', '2', '4', '3', 1],
#  ['4', '60', '1', '1', '3', 0],
#  ['5', '57', '4', '3', '3', 1],
#  ['4', '57', '1', '1', '3', 0],
#  ['6', '41', '2', '1', '3', 0],
#  ['4', '71', '2', '1', '3', 1],
#  ['4', '32', '2', '1', '3', 0],
#  ['4', '57', '2', '1', '3', 0],
#  ['4', '19', '1', '1', '3', 0],
#  ['4', '62', '2', '4', '3', 1],
#  ['5', '67', '4', '5', '3', 1],
#  ['4', '50', '4', '5', '3', 0],
#  ['4', '65', '2', '3', '2', 0],
#  ['4', '40', '2', '4', '2', 0],
#  ['6', '71', '4', '4', '3', 1],
#  ['6', '68', '4', '3', '3', 1],
#  ['4', '68', '1', '1', '3', 0],
#  ['4', '29', '1', '1', '3', 0],
#  ['4', '53', '2', '1', '3', 0],
#  ['5', '66', '4', '4', '3', 1],
#  ['4', '60', '3', '?', '4', 0],
#  ['5', '76', '4', '4', '3', 1],
#  ['4', '58', '2', '1', '2', 0],
#  ['5', '96', '3', '4', '3', 1],
#  ['5', '70', '4', '4', '3', 1],
#  ['4', '34', '2', '1', '3', 0],
#  ['4', '59', '2', '1', '3', 0],
#  ['4', '45', '3', '1', '3', 1],
#  ['5', '65', '4', '4', '3', 1],
#  ['4', '59', '1', '1', '3', 0],
#  ['4', '21', '2', '1', '3', 0],
#  ['3', '43', '2', '1', '3', 0],
#  ['4', '53', '1', '1', '3', 0],
#  ['4', '65', '2', '1', '3', 0],
#  ['4', '64', '2', '4', '3', 1],
#  ['4', '53', '4', '4', '3', 0],
#  ['4', '51', '1', '1', '3', 0],
#  ['4', '59', '2', '4', '3', 0],
#  ['4', '56', '2', '1', '3', 0],
#  ['4', '60', '2', '1', '3', 0],
#  ['4', '22', '1', '1', '3', 0],
#  ['4', '25', '2', '1', '3', 0],
#  ['6', '76', '3', '?', '3', 0],
#  ['5', '69', '4', '4', '3', 1],
#  ['4', '58', '2', '1', '3', 0],
#  ['5', '62', '4', '3', '3', 1],
#  ['4', '56', '4', '4', '3', 0],
#  ['4', '64', '1', '1', '3', 0],
#  ['4', '32', '2', '1', '3', 0],
#  ['5', '48', '?', '4', '?', 1],
#  ['5', '59', '4', '4', '2', 1],
#  ['4', '52', '1', '1', '3', 0],
#  ['4', '63', '4', '4', '3', 0],
#  ['5', '67', '4', '4', '3', 1],
#  ['5', '61', '4', '4', '3', 1],
#  ['5', '59', '4', '5', '3', 1],
#  ['5', '52', '4', '3', '3', 1],
#  ['4', '35', '4', '4', '3', 0],
#  ['5', '77', '3', '3', '3', 1],
#  ['5', '71', '4', '3', '3', 1],
#  ['5', '63', '4', '3', '3', 1],
#  ['4', '38', '2', '1', '2', 0],
#  ['5', '72', '4', '3', '3', 1],
#  ['4', '76', '4', '3', '3', 1],
#  ['4', '53', '3', '3', '3', 0],
#  ['4', '67', '4', '5', '3', 0],
#  ['5', '69', '2', '4', '3', 1],
#  ['4', '54', '1', '1', '3', 0],
#  ['2', '35', '2', '1', '2', 0],
#  ['5', '68', '4', '3', '3', 1],
#  ['4', '68', '4', '4', '3', 0],
#  ['4', '67', '2', '4', '3', 1],
#  ['3', '39', '1', '1', '3', 0],
#  ['4', '44', '2', '1', '3', 0],
#  ['4', '33', '1', '1', '3', 0],
#  ['4', '60', '?', '4', '3', 0],
#  ['4', '58', '1', '1', '3', 0],
#  ['4', '31', '1', '1', '3', 0],
#  ['3', '23', '1', '1', '3', 0],
#  ['5', '56', '4', '5', '3', 1],
#  ['4', '69', '2', '1', '3', 1],
#  ['6', '63', '1', '1', '3', 0],
#  ['4', '65', '1', '1', '3', 1],
#  ['4', '44', '2', '1', '2', 0],
#  ['4', '62', '3', '3', '3', 1],
#  ['4', '67', '4', '4', '3', 1],
#  ['4', '56', '2', '1', '3', 0],
#  ['4', '52', '3', '4', '3', 0],
#  ['4', '43', '1', '1', '3', 1],
#  ['4', '41', '4', '3', '2', 1],
#  ['4', '42', '3', '4', '2', 0],
#  ['3', '46', '1', '1', '3', 0],
#  ['5', '55', '4', '4', '3', 1],
#  ['5', '58', '4', '4', '2', 1],
#  ['5', '87', '4', '4', '3', 1],
#  ['4', '66', '2', '1', '3', 0],
#  ['0', '72', '4', '3', '3', 1],
#  ['5', '60', '4', '3', '3', 1],
#  ['5', '83', '4', '4', '2', 1],
#  ['4', '31', '2', '1', '3', 0],
#  ['4', '53', '2', '1', '3', 0],
#  ['4', '64', '2', '3', '3', 0],
#  ['5', '31', '4', '4', '2', 1],
#  ['5', '62', '4', '4', '2', 1],
#  ['4', '56', '2', '1', '3', 0],
#  ['5', '58', '4', '4', '3', 1],
#  ['4', '67', '1', '4', '3', 0],
#  ['5', '75', '4', '5', '3', 1],
#  ['5', '65', '3', '4', '3', 1],
#  ['5', '74', '3', '2', '3', 1],
#  ['4', '59', '2', '1', '3', 0],
#  ['4', '57', '4', '4', '4', 1],
#  ['4', '76', '3', '2', '3', 0],
#  ['4', '63', '1', '4', '3', 0],
#  ['4', '44', '1', '1', '3', 0],
#  ['4', '42', '3', '1', '2', 0],
#  ['4', '35', '3', '?', '2', 0],
#  ['5', '65', '4', '3', '3', 1],
#  ['4', '70', '2', '1', '3', 0],
#  ['4', '48', '1', '1', '3', 0],
#  ['4', '74', '1', '1', '1', 1],
#  ['6', '40', '?', '3', '4', 1],
#  ['4', '63', '1', '1', '3', 0],
#  ['5', '60', '4', '4', '3', 1],
#  ['5', '86', '4', '3', '3', 1],
#  ['4', '27', '1', '1', '3', 0],
#  ['4', '71', '4', '5', '2', 1],
#  ['5', '85', '4', '4', '3', 1],
#  ['4', '51', '3', '3', '3', 0],
#  ['6', '72', '4', '3', '3', 1],
#  ['5', '52', '4', '4', '3', 1],
#  ['4', '66', '2', '1', '3', 0],
#  ['5', '71', '4', '5', '3', 1],
#  ['4', '42', '2', '1', '3', 0],
#  ['4', '64', '4', '4', '2', 1],
#  ['4', '41', '2', '2', '3', 0],
#  ['4', '50', '2', '1', '3', 0],
#  ['4', '30', '1', '1', '3', 0],
#  ['4', '67', '1', '1', '3', 0],
#  ['5', '62', '4', '4', '3', 1],
#  ['4', '46', '2', '1', '2', 0],
#  ['4', '35', '1', '1', '3', 0],
#  ['4', '53', '1', '1', '2', 0],
#  ['4', '59', '2', '1', '3', 0],
#  ['4', '19', '3', '1', '3', 0],
#  ['5', '86', '2', '1', '3', 1],
#  ['4', '72', '2', '1', '3', 0],
#  ['4', '37', '2', '1', '2', 0],
#  ['4', '46', '3', '1', '3', 1],
#  ['4', '45', '1', '1', '3', 0],
#  ['4', '48', '4', '5', '3', 0],
#  ['4', '58', '4', '4', '3', 1],
#  ['4', '42', '1', '1', '3', 0],
#  ['4', '56', '2', '4', '3', 1],
#  ['4', '47', '2', '1', '3', 0],
#  ['4', '49', '4', '4', '3', 1],
#  ['5', '76', '2', '5', '3', 1],
#  ['5', '62', '4', '5', '3', 1],
#  ['5', '64', '4', '4', '3', 1],
#  ['5', '53', '4', '3', '3', 1],
#  ['4', '70', '4', '2', '2', 1],
#  ['5', '55', '4', '4', '3', 1],
#  ['4', '34', '4', '4', '3', 0],
#  ['5', '76', '4', '4', '3', 1],
#  ['4', '39', '1', '1', '3', 0],
#  ['2', '23', '1', '1', '3', 0],
#  ['4', '19', '1', '1', '3', 0],
#  ['5', '65', '4', '5', '3', 1],
#  ['4', '57', '2', '1', '3', 0],
#  ['5', '41', '4', '4', '3', 1],
#  ['4', '36', '4', '5', '3', 1],
#  ['4', '62', '3', '3', '3', 0],
#  ['4', '69', '2', '1', '3', 0],
#  ['4', '41', '3', '1', '3', 0],
#  ['3', '51', '2', '4', '3', 0],
#  ['5', '50', '3', '2', '3', 1],
#  ['4', '47', '4', '4', '3', 0],
#  ['4', '54', '4', '5', '3', 1],
#  ['5', '52', '4', '4', '3', 1],
#  ['4', '30', '1', '1', '3', 0],
#  ['3', '48', '4', '4', '3', 1],
#  ['5', '?', '4', '4', '3', 1],
#  ['4', '65', '2', '4', '3', 1],
#  ['4', '50', '1', '1', '3', 0],
#  ['5', '65', '4', '5', '3', 1],
#  ['5', '66', '4', '3', '3', 1],
#  ['6', '41', '3', '3', '2', 1],
#  ['5', '72', '3', '2', '3', 1],
#  ['4', '42', '1', '1', '1', 1],
#  ['4', '80', '4', '4', '3', 1],
#  ['0', '45', '2', '4', '3', 0],
#  ['4', '41', '1', '1', '3', 0],
#  ['4', '72', '3', '3', '3', 1],
#  ['4', '60', '4', '5', '3', 0],
#  ['5', '67', '4', '3', '3', 1],
#  ['4', '55', '2', '1', '3', 0],
#  ['4', '61', '3', '4', '3', 1],
#  ['4', '55', '3', '4', '3', 1],
#  ['4', '52', '4', '4', '3', 1],
#  ['4', '42', '1', '1', '3', 0],
#  ['5', '63', '4', '4', '3', 1],
#  ['4', '62', '4', '5', '3', 1],
#  ['4', '46', '1', '1', '3', 0],
#  ['4', '65', '2', '1', '3', 0],
#  ['4', '57', '3', '3', '3', 1],
#  ['4', '66', '4', '5', '3', 1],
#  ['4', '45', '1', '1', '3', 0],
#  ['4', '77', '4', '5', '3', 1],
#  ['4', '35', '1', '1', '3', 0],
#  ['4', '50', '4', '5', '3', 1],
#  ['4', '57', '4', '4', '3', 0],
#  ['4', '74', '3', '1', '3', 1],
#  ['4', '59', '4', '5', '3', 0],
#  ['4', '51', '1', '1', '3', 0],
#  ['4', '42', '3', '4', '3', 1],
#  ['4', '35', '2', '4', '3', 0],
#  ['4', '42', '1', '1', '3', 0],
#  ['4', '43', '2', '1', '3', 0],
#  ['4', '62', '4', '4', '3', 1],
#  ['4', '27', '2', '1', '3', 0],
#  ['5', '?', '4', '3', '3', 1],
#  ['4', '57', '4', '4', '3', 1],
#  ['4', '59', '2', '1', '3', 0],
#  ['5', '40', '3', '2', '3', 1],
#  ['4', '20', '1', '1', '3', 0],
#  ['5', '74', '4', '3', '3', 1],
#  ['4', '22', '1', '1', '3', 0],
#  ['4', '57', '4', '3', '3', 0],
#  ['4', '57', '4', '3', '3', 1],
#  ['4', '55', '2', '1', '2', 0],
#  ['4', '62', '2', '1', '3', 0],
#  ['4', '54', '1', '1', '3', 0],
#  ['4', '71', '1', '1', '3', 1],
#  ['4', '65', '3', '3', '3', 0],
#  ['4', '68', '4', '4', '3', 0],
#  ['4', '64', '1', '1', '3', 0],
#  ['4', '54', '2', '4', '3', 0],
#  ['4', '48', '4', '4', '3', 1],
#  ['4', '58', '4', '3', '3', 0],
#  ['5', '58', '3', '4', '3', 1],
#  ['4', '70', '1', '1', '1', 0],
#  ['5', '70', '1', '4', '3', 1],
#  ['4', '59', '2', '1', '3', 0],
#  ['4', '57', '2', '4', '3', 0],
#  ['4', '53', '4', '5', '3', 0],
#  ['4', '54', '4', '4', '3', 1],
#  ['4', '53', '2', '1', '3', 0],
#  ['0', '71', '4', '4', '3', 1],
#  ['5', '67', '4', '5', '3', 1],
#  ['4', '68', '4', '4', '3', 1],
#  ['4', '56', '2', '4', '3', 0],
#  ['4', '35', '2', '1', '3', 0],
#  ['4', '52', '4', '4', '3', 1],
#  ['4', '47', '2', '1', '3', 0],
#  ['4', '56', '4', '5', '3', 1],
#  ['4', '64', '4', '5', '3', 0],
#  ['5', '66', '4', '5', '3', 1],
#  ['4', '62', '3', '3', '3', 0]]

# %%
#removing nan values
for i in range(0,len(d)):
    j=0
    while(True):
        if (type(d[i][j])==float and math.isnan(d[i][j])) :
            del d[i][j]
            j-=1
        j+=1
        if (j>len(d[i])-1):
            break

d
# Out:
# [['5', '67', '3', '5', '3', 1],
#  ['4', '43', '1', '1', '?', 1],
#  ['5', '58', '4', '5', '3', 1],
#  ['4', '28', '1', '1', '3', 0],
#  ['5', '74', '1', '5', '?', 1],
#  ['4', '65', '1', '?', '3', 0],
#  ['4', '70', '?', '?', '3', 0],
#  ['5', '42', '1', '?', '3', 0],
#  ['5', '57', '1', '5', '3', 1],
#  ['5', '60', '?', '5', '1', 1],
#  ['5', '76', '1', '4', '3', 1],
#  ['3', '42', '2', '1', '3', 1],
#  ['4', '64', '1', '?', '3', 0],
#  ['4', '36', '3', '1', '2', 0],
#  ['4', '60', '2', '1', '2', 0],
#  ['4', '54', '1', '1', '3', 0],
#  ['3', '52', '3', '4', '3', 0],
#  ['4', '59', '2', '1', '3', 1],
#  ['4', '54', '1', '1', '3', 1],
#  ['4', '40', '1', '?', '?', 0],
#  ['?', '66', '?', '?', '1', 1],
#  ['5', '56', '4', '3', '1', 1],
#  ['4', '43', '1', '?', '?', 0],
#  ['5', '42', '4', '4', '3', 1],
#  ['4', '59', '2', '4', '3', 1],
#  ['5', '75', '4', '5', '3', 1],
#  ['2', '66', '1', '1', '?', 0],
#  ['5', '63', '3', '?', '3', 0],
#  ['5', '45', '4', '5', '3', 1],
#  ['5', '55', '4', '4', '3', 0],
#  ['4', '46', '1', '5', '2', 0],
#  ['5', '54', '4', '4', '3', 1],
#  ['5', '57', '4', '4', '3', 1],
#  ['4', '39', '1', '1', '2', 0],
#  ['4', '81', '1', '1', '3', 0],
#  ['4', '77', '3', '?', '?', 0],
#  ['4', '60', '2', '1', '3', 0],
#  ['5', '67', '3', '4', '2', 1],
#  ['4', '48', '4', '5', '?', 1],
#  ['4', '55', '3', '4', '2', 0],
#  ['4', '59', '2', '1', '?', 0],
#  ['4', '78', '1', '1', '1', 0],
#  ['4', '50', '1', '1', '3', 0],
#  ['4', '61', '2', '1', '?', 0],
#  ['5', '62', '3', '5', '2', 1],
#  ['5', '44', '2', '4', '?', 1],
#  ['5', '64', '4', '5', '3', 1],
#  ['4', '23', '1', '1', '?', 0],
#  ['2', '42', '?', '?', '4', 0],
#  ['5', '67', '4', '5', '3', 1],
#  ['4', '74', '2', '1', '2', 0],
#  ['5', '80', '3', '5', '3', 1],
#  ['4', '23', '1', '1', '?', 0],
#  ['4', '63', '2', '1', '?', 0],
#  ['4', '53', '?', '5', '3', 1],
#  ['4', '43', '3', '4', '?', 0],
#  ['4', '49', '2', '1', '1', 0],
#  ['5', '51', '2', '4', '?', 0],
#  ['4', '45', '2', '1', '?', 0],
#  ['5', '59', '2', '?', '?', 1],
#  ['5', '52', '4', '3', '3', 1],
#  ['5', '60', '4', '3', '3', 1],
#  ['4', '57', '2', '5', '3', 0],
#  ['3', '57', '2', '1', '?', 0],
#  ['5', '74', '4', '4', '3', 1],
#  ['4', '25', '2', '1', '?', 0],
#  ['4', '49', '1', '1', '3', 0],
#  ['5', '72', '4', '3', '?', 1],
#  ['4', '45', '2', '1', '3', 0],
#  ['4', '64', '2', '1', '3', 0],
#  ['4', '73', '2', '1', '2', 0],
#  ['5', '68', '4', '3', '3', 1],
#  ['5', '52', '4', '5', '3', 0],
#  ['5', '66', '4', '4', '3', 1],
#  ['5', '70', '?', '4', '?', 1],
#  ['4', '25', '1', '1', '3', 0],
#  ['5', '74', '1', '1', '2', 1],
#  ['4', '64', '1', '1', '3', 0],
#  ['5', '60', '4', '3', '2', 1],
#  ['5', '67', '2', '4', '1', 0],
#  ['4', '67', '4', '5', '3', 0],
#  ['5', '44', '4', '4', '2', 1],
#  ['3', '68', '1', '1', '3', 1],
#  ['4', '57', '?', '4', '1', 0],
#  ['5', '51', '4', '?', '?', 1],
#  ['4', '33', '1', '?', '?', 0],
#  ['5', '58', '4', '4', '3', 1],
#  ['5', '36', '1', '?', '?', 0],
#  ['4', '63', '1', '1', '?', 0],
#  ['5', '62', '1', '5', '3', 1],
#  ['4', '73', '3', '4', '3', 1],
#  ['4', '80', '4', '4', '3', 1],
#  ['4', '67', '1', '1', '?', 0],
#  ['5', '59', '2', '1', '3', 1],
#  ['5', '60', '1', '?', '3', 0],
#  ['5', '54', '4', '4', '3', 1],
#  ['4', '40', '1', '1', '?', 0],
#  ['4', '47', '2', '1', '?', 0],
#  ['5', '62', '4', '4', '3', 0],
#  ['4', '33', '2', '1', '3', 0],
#  ['5', '59', '2', '?', '?', 0],
#  ['4', '65', '2', '?', '?', 0],
#  ['4', '58', '4', '4', '?', 0],
#  ['4', '29', '2', '?', '?', 0],
#  ['4', '58', '1', '1', '?', 0],
#  ['4', '54', '1', '1', '?', 0],
#  ['4', '44', '1', '1', '?', 1],
#  ['3', '34', '2', '1', '?', 0],
#  ['4', '57', '1', '1', '3', 0],
#  ['5', '33', '4', '4', '?', 1],
#  ['4', '45', '4', '4', '3', 0],
#  ['5', '71', '4', '4', '3', 1],
#  ['5', '59', '4', '4', '2', 0],
#  ['4', '56', '2', '1', '?', 0],
#  ['4', '40', '3', '4', '?', 0],
#  ['4', '56', '1', '1', '3', 0],
#  ['4', '45', '2', '1', '?', 0],
#  ['4', '57', '2', '1', '2', 0],
#  ['5', '55', '3', '4', '3', 1],
#  ['5', '84', '4', '5', '3', 0],
#  ['5', '51', '4', '4', '3', 1],
#  ['4', '43', '1', '1', '?', 0],
#  ['4', '24', '2', '1', '2', 0],
#  ['4', '66', '1', '1', '3', 0],
#  ['5', '33', '4', '4', '3', 0],
#  ['4', '59', '4', '3', '2', 0],
#  ['4', '76', '2', '3', '?', 0],
#  ['4', '40', '1', '1', '?', 0],
#  ['4', '52', '?', '4', '?', 0],
#  ['5', '40', '4', '5', '3', 1],
#  ['5', '67', '4', '4', '3', 1],
#  ['5', '75', '4', '3', '3', 1],
#  ['5', '86', '4', '4', '3', 0],
#  ['4', '60', '2', '?', '?', 0],
#  ['5', '66', '4', '4', '3', 1],
#  ['5', '46', '4', '5', '3', 1],
#  ['4', '59', '4', '4', '3', 1],
#  ['5', '65', '4', '4', '3', 1],
#  ['4', '53', '1', '1', '3', 0],
#  ['5', '67', '3', '5', '3', 1],
#  ['5', '80', '4', '5', '3', 1],
#  ['4', '55', '2', '1', '3', 0],
#  ['4', '48', '1', '1', '?', 0],
#  ['4', '47', '1', '1', '2', 0],
#  ['4', '50', '2', '1', '?', 0],
#  ['5', '62', '4', '5', '3', 1],
#  ['5', '63', '4', '4', '3', 1],
#  ['4', '63', '4', '?', '3', 1],
#  ['4', '71', '4', '4', '3', 1],
#  ['4', '41', '1', '1', '3', 0],
#  ['5', '57', '4', '4', '4', 1],
#  ['5', '71', '4', '4', '4', 1],
#  ['4', '66', '1', '1', '3', 0],
#  ['4', '47', '2', '4', '2', 0],
#  ['3', '34', '4', '4', '3', 0],
#  ['4', '59', '3', '4', '3', 0],
#  ['5', '55', '2', '?', '?', 1],
#  ['4', '51', '?', '?', '3', 0],
#  ['4', '62', '2', '1', '?', 0],
#  ['4', '58', '4', '?', '3', 1],
#  ['5', '67', '4', '4', '3', 1],
#  ['4', '41', '2', '1', '3', 0],
#  ['4', '23', '3', '1', '3', 0],
#  ['4', '53', '?', '4', '3', 0],
#  ['4', '42', '2', '1', '3', 0],
#  ['5', '87', '4', '5', '3', 1],
#  ['4', '68', '1', '1', '3', 1],
#  ['4', '64', '1', '1', '3', 0],
#  ['5', '54', '3', '5', '3', 1],
#  ['5', '86', '4', '5', '3', 1],
#  ['4', '21', '2', '1', '3', 0],
#  ['4', '39', '1', '1', '?', 0],
#  ['4', '53', '4', '4', '3', 0],
#  ['4', '44', '4', '4', '3', 0],
#  ['4', '54', '1', '1', '3', 0],
#  ['5', '63', '4', '5', '3', 1],
#  ['4', '62', '2', '1', '?', 0],
#  ['4', '45', '2', '1', '2', 0],
#  ['5', '71', '4', '5', '3', 0],
#  ['5', '49', '4', '4', '3', 1],
#  ['4', '49', '4', '4', '3', 0],
#  ['5', '66', '4', '4', '4', 0],
#  ['4', '19', '1', '1', '3', 0],
#  ['4', '35', '1', '1', '2', 0],
#  ['4', '71', '3', '3', '?', 1],
#  ['5', '74', '4', '5', '3', 1],
#  ['5', '37', '4', '4', '3', 1],
#  ['4', '67', '1', '?', '3', 0],
#  ['5', '81', '3', '4', '3', 1],
#  ['5', '59', '4', '4', '3', 1],
#  ['4', '34', '1', '1', '3', 0],
#  ['5', '79', '4', '3', '3', 1],
#  ['5', '60', '3', '1', '3', 0],
#  ['4', '41', '1', '1', '3', 1],
#  ['4', '50', '1', '1', '3', 0],
#  ['5', '85', '4', '4', '3', 1],
#  ['4', '46', '1', '1', '3', 0],
#  ['5', '66', '4', '4', '3', 1],
#  ['4', '73', '3', '1', '2', 0],
#  ['4', '55', '1', '1', '3', 0],
#  ['4', '49', '2', '1', '3', 0],
#  ['3', '49', '4', '4', '3', 0],
#  ['4', '51', '4', '5', '3', 1],
#  ['2', '48', '4', '4', '3', 0],
#  ['4', '58', '4', '5', '3', 0],
#  ['5', '72', '4', '5', '3', 1],
#  ['4', '46', '2', '3', '3', 0],
#  ['4', '43', '4', '3', '3', 1],
#  ['?', '52', '4', '4', '3', 0],
#  ['4', '66', '2', '1', '?', 0],
#  ['4', '46', '1', '1', '1', 0],
#  ['4', '69', '3', '1', '3', 0],
#  ['2', '59', '1', '1', '?', 1],
#  ['5', '43', '2', '1', '3', 1],
#  ['5', '76', '4', '5', '3', 1],
#  ['4', '46', '1', '1', '3', 0],
#  ['4', '59', '2', '4', '3', 0],
#  ['4', '57', '1', '1', '3', 0],
#  ['5', '43', '4', '5', '?', 0],
#  ['3', '45', '2', '1', '3', 0],
#  ['3', '43', '2', '1', '3', 0],
#  ['4', '45', '2', '1', '3', 0],
#  ['5', '57', '4', '5', '3', 1],
#  ['5', '79', '4', '4', '3', 1],
#  ['5', '54', '2', '1', '3', 1],
#  ['4', '40', '3', '4', '3', 0],
#  ['5', '63', '4', '4', '3', 1],
#  ['2', '55', '1', '?', '1', 0],
#  ['4', '52', '2', '1', '3', 0],
#  ['4', '38', '1', '1', '3', 0],
#  ['3', '72', '4', '3', '3', 0],
#  ['5', '80', '4', '3', '3', 1],
#  ['5', '76', '4', '3', '3', 1],
#  ['4', '62', '3', '1', '3', 0],
#  ['5', '64', '4', '5', '3', 1],
#  ['5', '42', '4', '5', '3', 0],
#  ['3', '60', '?', '3', '1', 0],
#  ['4', '64', '4', '5', '3', 0],
#  ['4', '63', '4', '4', '3', 1],
#  ['4', '24', '2', '1', '2', 0],
#  ['5', '72', '4', '4', '3', 1],
#  ['4', '63', '2', '1', '3', 0],
#  ['4', '46', '1', '1', '3', 0],
#  ['3', '33', '1', '1', '3', 0],
#  ['5', '76', '4', '4', '3', 1],
#  ['4', '36', '2', '3', '3', 0],
#  ['4', '40', '2', '1', '3', 0],
#  ['5', '58', '1', '5', '3', 1],
#  ['4', '43', '2', '1', '3', 0],
#  ['3', '42', '1', '1', '3', 0],
#  ['4', '32', '1', '1', '3', 0],
#  ['5', '57', '4', '4', '2', 1],
#  ['4', '37', '1', '1', '3', 0],
#  ['4', '70', '4', '4', '3', 1],
#  ['5', '56', '4', '2', '3', 1],
#  ['3', '76', '?', '3', '2', 0],
#  ['5', '73', '4', '4', '3', 1],
#  ['5', '77', '4', '5', '3', 1],
#  ['5', '67', '4', '4', '1', 1],
#  ['5', '71', '4', '3', '3', 1],
#  ['5', '65', '4', '4', '3', 1],
#  ['4', '43', '1', '1', '3', 0],
#  ['4', '40', '2', '1', '?', 0],
#  ['4', '49', '2', '1', '3', 0],
#  ['5', '76', '4', '2', '3', 1],
#  ['4', '55', '4', '4', '3', 0],
#  ['5', '72', '4', '5', '3', 1],
#  ['3', '53', '4', '3', '3', 0],
#  ['5', '75', '4', '4', '3', 1],
#  ['5', '61', '4', '5', '3', 1],
#  ['5', '67', '4', '4', '3', 1],
#  ['5', '55', '4', '2', '3', 1],
#  ['5', '66', '4', '4', '3', 1],
#  ['2', '76', '1', '1', '2', 0],
#  ['4', '57', '4', '4', '3', 1],
#  ['5', '71', '3', '1', '3', 0],
#  ['5', '70', '4', '5', '3', 1],
#  ['4', '35', '4', '2', '?', 0],
#  ['5', '79', '1', '?', '3', 1],
#  ['4', '63', '2', '1', '3', 0],
#  ['5', '40', '1', '4', '3', 1],
#  ['4', '41', '1', '1', '3', 0],
#  ['4', '47', '2', '1', '2', 0],
#  ['4', '68', '1', '1', '3', 1],
#  ['4', '64', '4', '3', '3', 1],
#  ['4', '65', '4', '4', '?', 1],
#  ['4', '73', '4', '3', '3', 0],
#  ['4', '39', '4', '3', '3', 0],
#  ['5', '55', '4', '5', '4', 1],
#  ['5', '53', '3', '4', '4', 0],
#  ['5', '66', '4', '4', '3', 1],
#  ['4', '43', '3', '1', '2', 0],
#  ['5', '44', '4', '5', '3', 1],
#  ['4', '77', '4', '4', '3', 1],
#  ['4', '62', '2', '4', '3', 0],
#  ['5', '80', '4', '4', '3', 1],
#  ['4', '33', '4', '4', '3', 0],
#  ['4', '50', '4', '5', '3', 1],
#  ['4', '71', '1', '?', '3', 0],
#  ['5', '46', '4', '4', '3', 1],
#  ['5', '49', '4', '5', '3', 1],
#  ['4', '53', '1', '1', '3', 0],
#  ['3', '46', '2', '1', '2', 0],
#  ['4', '57', '1', '1', '3', 0],
#  ['4', '54', '3', '1', '3', 0],
#  ['4', '54', '1', '?', '?', 0],
#  ['2', '49', '2', '1', '2', 0],
#  ['4', '47', '3', '1', '3', 0],
#  ['4', '40', '1', '1', '3', 0],
#  ['4', '45', '1', '1', '3', 0],
#  ['4', '50', '4', '5', '3', 1],
#  ['5', '54', '4', '4', '3', 1],
#  ['4', '67', '4', '1', '3', 1],
#  ['4', '77', '4', '4', '3', 1],
#  ['4', '66', '4', '3', '3', 0],
#  ['4', '71', '2', '?', '3', 1],
#  ['4', '36', '2', '3', '3', 0],
#  ['4', '69', '4', '4', '3', 0],
#  ['4', '48', '1', '1', '3', 0],
#  ['4', '64', '4', '4', '3', 1],
#  ['4', '71', '4', '2', '3', 1],
#  ['5', '60', '4', '3', '3', 1],
#  ['4', '24', '1', '1', '3', 0],
#  ['5', '34', '4', '5', '2', 1],
#  ['4', '79', '1', '1', '2', 0],
#  ['4', '45', '1', '1', '3', 0],
#  ['4', '37', '2', '1', '2', 0],
#  ['4', '42', '1', '1', '2', 0],
#  ['4', '72', '4', '4', '3', 1],
#  ['5', '60', '4', '5', '3', 1],
#  ['5', '85', '3', '5', '3', 1],
#  ['4', '51', '1', '1', '3', 0],
#  ['5', '54', '4', '5', '3', 1],
#  ['5', '55', '4', '3', '3', 1],
#  ['4', '64', '4', '4', '3', 0],
#  ['5', '67', '4', '5', '3', 1],
#  ['5', '75', '4', '3', '3', 1],
#  ['5', '87', '4', '4', '3', 1],
#  ['4', '46', '4', '4', '3', 1],
#  ['4', '59', '2', '1', '?', 0],
#  ['5', '46', '4', '3', '3', 1],
#  ['5', '61', '1', '1', '3', 1],
#  ['4', '44', '1', '4', '3', 0],
#  ['4', '32', '1', '1', '3', 0],
#  ['4', '62', '1', '1', '3', 0],
#  ['5', '59', '4', '5', '3', 1],
#  ['4', '61', '4', '1', '3', 0],
#  ['5', '78', '4', '4', '3', 1],
#  ['5', '42', '4', '5', '3', 0],
#  ['4', '45', '1', '2', '3', 0],
#  ['5', '34', '2', '1', '3', 1],
#  ['5', '39', '4', '3', '?', 1],
#  ['4', '27', '3', '1', '3', 0],
#  ['4', '43', '1', '1', '3', 0],
#  ['5', '83', '4', '4', '3', 1],
#  ['4', '36', '2', '1', '3', 0],
#  ['4', '37', '2', '1', '3', 0],
#  ['4', '56', '3', '1', '3', 1],
#  ['5', '55', '4', '4', '3', 1],
#  ['5', '46', '3', '?', '3', 0],
#  ['4', '88', '4', '4', '3', 1],
#  ['5', '71', '4', '4', '3', 1],
#  ['4', '41', '2', '1', '3', 0],
#  ['5', '49', '4', '4', '3', 1],
#  ['3', '51', '1', '1', '4', 0],
#  ['4', '39', '1', '3', '3', 0],
#  ['4', '46', '2', '1', '3', 0],
#  ['5', '52', '4', '4', '3', 1],
#  ['5', '58', '4', '4', '3', 1],
#  ['4', '67', '4', '5', '3', 1],
#  ['5', '80', '4', '4', '3', 1],
#  ['3', '46', '1', '?', '?', 0],
#  ['3', '43', '1', '?', '?', 0],
#  ['4', '45', '1', '1', '3', 0],
#  ['5', '68', '4', '4', '3', 1],
#  ['4', '54', '4', '4', '?', 1],
#  ['4', '44', '2', '3', '3', 0],
#  ['5', '74', '4', '3', '3', 1],
#  ['5', '55', '4', '5', '3', 0],
#  ['4', '49', '4', '4', '3', 1],
#  ['4', '49', '1', '1', '3', 0],
#  ['5', '50', '4', '3', '3', 1],
#  ['5', '52', '3', '5', '3', 1],
#  ['4', '45', '1', '1', '3', 0],
#  ['4', '66', '1', '1', '3', 0],
#  ['4', '68', '4', '4', '3', 1],
#  ['4', '72', '2', '1', '3', 0],
#  ['5', '64', '?', '?', '3', 0],
#  ['2', '49', '?', '3', '3', 0],
#  ['3', '44', '?', '4', '3', 0],
#  ['5', '74', '4', '4', '3', 1],
#  ['5', '58', '4', '4', '3', 1],
#  ['4', '77', '2', '3', '3', 0],
#  ['4', '49', '3', '1', '3', 0],
#  ['4', '34', '?', '?', '4', 0],
#  ['5', '60', '4', '3', '3', 1],
#  ['5', '69', '4', '3', '3', 1],
#  ['4', '53', '2', '1', '3', 0],
#  ['3', '46', '3', '4', '3', 0],
#  ['5', '74', '4', '4', '3', 1],
#  ['4', '58', '1', '1', '3', 0],
#  ['5', '68', '4', '4', '3', 1],
#  ['5', '46', '4', '3', '3', 0],
#  ['5', '61', '2', '4', '3', 1],
#  ['5', '70', '4', '3', '3', 1],
#  ['5', '37', '4', '4', '3', 1],
#  ['3', '65', '4', '5', '3', 1],
#  ['4', '67', '4', '4', '3', 0],
#  ['5', '69', '3', '4', '3', 0],
#  ['5', '76', '4', '4', '3', 1],
#  ['4', '65', '4', '3', '3', 0],
#  ['5', '72', '4', '2', '3', 1],
#  ['4', '62', '4', '2', '3', 0],
#  ['5', '42', '4', '4', '3', 1],
#  ['5', '66', '4', '3', '3', 1],
#  ['5', '48', '4', '4', '3', 1],
#  ['4', '35', '1', '1', '3', 0],
#  ['5', '60', '4', '4', '3', 1],
#  ['5', '67', '4', '2', '3', 1],
#  ['5', '78', '4', '4', '3', 1],
#  ['4', '66', '1', '1', '3', 1],
#  ['4', '26', '1', '1', '?', 0],
#  ['4', '48', '1', '1', '3', 0],
#  ['4', '31', '1', '1', '3', 0],
#  ['5', '43', '4', '3', '3', 1],
#  ['5', '72', '2', '4', '3', 0],
#  ['5', '66', '1', '1', '3', 1],
#  ['4', '56', '4', '4', '3', 0],
#  ['5', '58', '4', '5', '3', 1],
#  ['5', '33', '2', '4', '3', 1],
#  ['4', '37', '1', '1', '3', 0],
#  ['5', '36', '4', '3', '3', 1],
#  ['4', '39', '2', '3', '3', 0],
#  ['4', '39', '4', '4', '3', 1],
#  ['5', '83', '4', '4', '3', 1],
#  ['4', '68', '4', '5', '3', 1],
#  ['5', '63', '3', '4', '3', 1],
#  ['5', '78', '4', '4', '3', 1],
#  ['4', '38', '2', '3', '3', 0],
#  ['5', '46', '4', '3', '3', 1],
#  ['5', '60', '4', '4', '3', 1],
#  ['5', '56', '2', '3', '3', 1],
#  ['4', '33', '1', '1', '3', 0],
#  ['4', '?', '4', '5', '3', 1],
#  ['4', '69', '1', '5', '3', 1],
#  ['5', '66', '1', '4', '3', 1],
#  ['4', '72', '1', '3', '3', 0],
#  ['4', '29', '1', '1', '3', 0],
#  ['5', '54', '4', '5', '3', 1],
#  ['5', '80', '4', '4', '3', 1],
#  ['5', '68', '4', '3', '3', 1],
#  ['4', '35', '2', '1', '3', 0],
#  ['4', '57', '3', '?', '3', 0],
#  ['5', '?', '4', '4', '3', 1],
#  ['4', '50', '1', '1', '3', 0],
#  ['4', '32', '4', '3', '3', 0],
#  ['0', '69', '4', '5', '3', 1],
#  ['4', '71', '4', '5', '3', 1],
#  ['5', '87', '4', '5', '3', 1],
#  ['3', '40', '2', '?', '3', 0],
#  ['4', '31', '1', '1', '?', 0],
#  ['4', '64', '1', '1', '3', 0],
#  ['5', '55', '4', '5', '3', 1],
#  ['4', '18', '1', '1', '3', 0],
#  ['3', '50', '2', '1', '?', 0],
#  ['4', '53', '1', '1', '3', 0],
#  ['5', '84', '4', '5', '3', 1],
#  ['5', '80', '4', '3', '3', 1],
#  ['4', '32', '1', '1', '3', 0],
#  ['5', '77', '3', '4', '3', 1],
#  ['4', '38', '1', '1', '3', 0],
#  ['5', '54', '4', '5', '3', 1],
#  ['4', '63', '1', '1', '3', 0],
#  ['4', '61', '1', '1', '3', 0],
#  ['4', '52', '1', '1', '3', 0],
#  ['4', '36', '1', '1', '3', 0],
#  ['4', '41', '?', '?', '3', 0],
#  ['4', '59', '1', '1', '3', 0],
#  ['5', '51', '4', '4', '2', 1],
#  ['4', '36', '1', '1', '3', 0],
#  ['5', '40', '4', '3', '3', 1],
#  ['4', '49', '1', '1', '3', 0],
#  ['4', '37', '2', '3', '3', 0],
#  ['4', '46', '1', '1', '3', 0],
#  ['4', '63', '1', '1', '3', 0],
#  ['4', '28', '2', '1', '3', 0],
#  ['4', '47', '2', '1', '3', 0],
#  ['4', '42', '2', '1', '3', 1],
#  ['5', '44', '4', '5', '3', 1],
#  ['4', '49', '4', '4', '3', 0],
#  ['5', '47', '4', '5', '3', 1],
#  ['5', '52', '4', '5', '3', 1],
#  ['4', '53', '1', '1', '3', 1],
#  ['5', '83', '3', '3', '3', 1],
#  ['4', '50', '4', '4', '?', 1],
#  ['5', '63', '4', '4', '3', 1],
#  ['4', '82', '?', '5', '3', 1],
#  ['4', '54', '1', '1', '3', 0],
#  ['4', '50', '4', '4', '3', 0],
#  ['5', '80', '4', '5', '3', 1],
#  ['5', '45', '2', '4', '3', 0],
#  ['5', '59', '4', '4', '?', 1],
#  ['4', '28', '2', '1', '3', 0],
#  ['4', '31', '1', '1', '3', 0],
#  ['4', '41', '2', '1', '3', 0],
#  ['4', '21', '3', '1', '3', 0],
#  ['5', '44', '3', '4', '3', 1],
#  ['5', '49', '4', '4', '3', 1],
#  ['5', '71', '4', '5', '3', 1],
#  ['5', '75', '4', '5', '3', 1],
#  ['4', '38', '2', '1', '3', 0],
#  ['4', '60', '1', '3', '3', 0],
#  ['5', '87', '4', '5', '3', 1],
#  ['4', '70', '4', '4', '3', 1],
#  ['5', '55', '4', '5', '3', 1],
#  ['3', '21', '1', '1', '3', 0],
#  ['4', '50', '1', '1', '3', 0],
#  ['5', '76', '4', '5', '3', 1],
#  ['4', '23', '1', '1', '3', 0],
#  ['3', '68', '?', '?', '3', 0],
#  ['4', '62', '4', '?', '3', 1],
#  ['5', '65', '1', '?', '3', 1],
#  ['5', '73', '4', '5', '3', 1],
#  ['4', '38', '2', '3', '3', 0],
#  ['2', '57', '1', '1', '3', 0],
#  ['5', '65', '4', '5', '3', 1],
#  ['5', '67', '2', '4', '3', 1],
#  ['5', '61', '2', '4', '3', 1],
#  ['5', '56', '4', '4', '3', 0],
#  ['5', '71', '2', '4', '3', 1],
#  ['4', '49', '2', '2', '3', 0],
#  ['4', '55', '?', '?', '3', 0],
#  ['4', '44', '2', '1', '3', 0],
#  ['0', '58', '4', '4', '3', 0],
#  ['4', '27', '2', '1', '3', 0],
#  ['5', '73', '4', '5', '3', 1],
#  ['4', '34', '2', '1', '3', 0],
#  ['5', '63', '?', '4', '3', 1],
#  ['4', '50', '2', '1', '3', 1],
#  ['4', '62', '2', '1', '3', 0],
#  ['3', '21', '3', '1', '3', 0],
#  ['4', '49', '2', '?', '3', 0],
#  ['4', '36', '3', '1', '3', 0],
#  ['4', '45', '2', '1', '3', 1],
#  ['5', '67', '4', '5', '3', 1],
#  ['4', '21', '1', '1', '3', 0],
#  ['4', '57', '2', '1', '3', 0],
#  ['5', '66', '4', '5', '3', 1],
#  ['4', '71', '4', '4', '3', 1],
#  ['5', '69', '3', '4', '3', 1],
#  ['6', '80', '4', '5', '3', 1],
#  ['3', '27', '2', '1', '3', 0],
#  ['4', '38', '2', '1', '3', 0],
#  ['4', '23', '2', '1', '3', 0],
#  ['5', '70', '?', '5', '3', 1],
#  ['4', '46', '4', '3', '3', 0],
#  ['4', '61', '2', '3', '3', 0],
#  ['5', '65', '4', '5', '3', 1],
#  ['4', '60', '4', '3', '3', 0],
#  ['5', '83', '4', '5', '3', 1],
#  ['5', '40', '4', '4', '3', 1],
#  ['2', '59', '?', '4', '3', 0],
#  ['4', '53', '3', '4', '3', 0],
#  ['4', '76', '4', '4', '3', 0],
#  ['5', '79', '1', '4', '3', 1],
#  ['5', '38', '2', '4', '3', 1],
#  ['4', '61', '3', '4', '3', 0],
#  ['4', '56', '2', '1', '3', 0],
#  ['4', '44', '2', '1', '3', 0],
#  ['4', '64', '3', '4', '?', 1],
#  ['4', '66', '3', '3', '3', 0],
#  ['4', '50', '3', '3', '3', 0],
#  ['4', '46', '1', '1', '3', 0],
#  ['4', '39', '1', '1', '3', 0],
#  ['4', '60', '3', '?', '?', 0],
#  ['5', '55', '4', '5', '3', 1],
#  ['4', '40', '2', '1', '3', 0],
#  ['4', '26', '1', '1', '3', 0],
#  ['5', '84', '3', '2', '3', 1],
#  ['4', '41', '2', '2', '3', 0],
#  ['4', '63', '1', '1', '3', 0],
#  ['2', '65', '?', '1', '2', 0],
#  ['4', '49', '1', '1', '3', 0],
#  ['4', '56', '2', '2', '3', 1],
#  ['5', '65', '4', '4', '3', 0],
#  ['4', '54', '1', '1', '3', 0],
#  ['4', '36', '1', '1', '3', 0],
#  ['5', '49', '4', '4', '3', 0],
#  ['4', '59', '4', '4', '3', 1],
#  ['5', '75', '4', '4', '3', 1],
#  ['5', '59', '4', '2', '3', 0],
#  ['5', '59', '4', '4', '3', 1],
#  ['4', '28', '4', '4', '3', 1],
#  ['5', '53', '4', '5', '3', 0],
#  ['5', '57', '4', '4', '3', 0],
#  ['5', '77', '4', '3', '4', 0],
#  ['5', '85', '4', '3', '3', 1],
#  ['4', '59', '4', '4', '3', 0],
#  ['5', '59', '1', '5', '3', 1],
#  ['4', '65', '3', '3', '3', 1],
#  ['4', '54', '2', '1', '3', 0],
#  ['5', '46', '4', '5', '3', 1],
#  ['4', '63', '4', '4', '3', 1],
#  ['4', '53', '1', '1', '3', 1],
#  ['4', '56', '1', '1', '3', 0],
#  ['5', '66', '4', '4', '3', 1],
#  ['5', '66', '4', '5', '3', 1],
#  ['4', '55', '1', '1', '3', 0],
#  ['4', '44', '1', '1', '3', 0],
#  ['5', '86', '3', '4', '3', 1],
#  ['5', '47', '4', '5', '3', 1],
#  ['5', '59', '4', '5', '3', 1],
#  ['5', '66', '4', '5', '3', 0],
#  ['5', '61', '4', '3', '3', 1],
#  ['3', '46', '?', '5', '?', 1],
#  ['4', '69', '1', '1', '3', 0],
#  ['5', '93', '1', '5', '3', 1],
#  ['4', '39', '1', '3', '3', 0],
#  ['5', '44', '4', '5', '3', 1],
#  ['4', '45', '2', '2', '3', 0],
#  ['4', '51', '3', '4', '3', 0],
#  ['4', '56', '2', '4', '3', 0],
#  ['4', '66', '4', '4', '3', 0],
#  ['5', '61', '4', '5', '3', 1],
#  ['4', '64', '3', '3', '3', 1],
#  ['5', '57', '2', '4', '3', 0],
#  ['5', '79', '4', '4', '3', 1],
#  ['4', '57', '2', '1', '?', 0],
#  ['4', '44', '4', '1', '1', 0],
#  ['4', '31', '2', '1', '3', 0],
#  ['4', '63', '4', '4', '3', 0],
#  ['4', '64', '1', '1', '3', 0],
#  ['5', '47', '4', '5', '3', 0],
#  ['5', '68', '4', '5', '3', 1],
#  ['4', '30', '1', '1', '3', 0],
#  ['5', '43', '4', '5', '3', 1],
#  ['4', '56', '1', '1', '3', 0],
#  ['4', '46', '2', '1', '3', 0],
#  ['4', '67', '2', '1', '3', 0],
#  ['5', '52', '4', '5', '3', 1],
#  ['4', '67', '4', '4', '3', 1],
#  ['4', '47', '2', '1', '3', 0],
#  ['5', '58', '4', '5', '3', 1],
#  ['4', '28', '2', '1', '3', 0],
#  ['4', '43', '1', '1', '3', 0],
#  ['4', '57', '2', '4', '3', 0],
#  ['5', '68', '4', '5', '3', 1],
#  ['4', '64', '2', '4', '3', 0],
#  ['4', '64', '2', '4', '3', 0],
#  ['5', '62', '4', '4', '3', 1],
#  ['4', '38', '4', '1', '3', 0],
#  ['5', '68', '4', '4', '3', 1],
#  ['4', '41', '2', '1', '3', 0],
#  ['4', '35', '2', '1', '3', 1],
#  ['4', '68', '2', '1', '3', 0],
#  ['5', '55', '4', '4', '3', 1],
#  ['5', '67', '4', '4', '3', 1],
#  ['4', '51', '4', '3', '3', 0],
#  ['2', '40', '1', '1', '3', 0],
#  ['5', '73', '4', '4', '3', 1],
#  ['4', '58', '?', '4', '3', 1],
#  ['4', '51', '?', '4', '3', 0],
#  ['3', '50', '?', '?', '3', 1],
#  ['5', '59', '4', '3', '3', 1],
#  ['6', '60', '3', '5', '3', 1],
#  ['4', '27', '2', '1', '?', 0],
#  ['5', '54', '4', '3', '3', 0],
#  ['4', '56', '1', '1', '3', 0],
#  ['5', '53', '4', '5', '3', 1],
#  ['4', '54', '2', '4', '3', 0],
#  ['5', '79', '1', '4', '3', 1],
#  ['5', '67', '4', '3', '3', 1],
#  ['5', '64', '3', '3', '3', 1],
#  ['4', '70', '1', '2', '3', 1],
#  ['5', '55', '4', '3', '3', 1],
#  ['5', '65', '3', '3', '3', 1],
#  ['5', '45', '4', '2', '3', 1],
#  ['4', '57', '4', '4', '?', 1],
#  ['5', '49', '1', '1', '3', 1],
#  ['4', '24', '2', '1', '3', 0],
#  ['4', '52', '1', '1', '3', 0],
#  ['4', '50', '2', '1', '3', 0],
#  ['4', '35', '1', '1', '3', 0],
#  ['5', '?', '3', '3', '3', 1],
#  ['5', '64', '4', '3', '3', 1],
#  ['5', '40', '4', '1', '1', 1],
#  ['5', '66', '4', '4', '3', 1],
#  ['4', '64', '4', '4', '3', 1],
#  ['5', '52', '4', '3', '3', 1],
#  ['5', '43', '1', '4', '3', 1],
#  ['4', '56', '4', '4', '3', 0],
#  ['4', '72', '3', '?', '3', 0],
#  ['6', '51', '4', '4', '3', 1],
#  ['4', '79', '4', '4', '3', 1],
#  ['4', '22', '2', '1', '3', 0],
#  ['4', '73', '2', '1', '3', 0],
#  ['4', '53', '3', '4', '3', 0],
#  ['4', '59', '2', '1', '3', 1],
#  ['4', '46', '4', '4', '2', 0],
#  ['5', '66', '4', '4', '3', 1],
#  ['4', '50', '4', '3', '3', 1],
#  ['4', '58', '1', '1', '3', 1],
#  ['4', '55', '1', '1', '3', 0],
#  ['4', '62', '2', '4', '3', 1],
#  ['4', '60', '1', '1', '3', 0],
#  ['5', '57', '4', '3', '3', 1],
#  ['4', '57', '1', '1', '3', 0],
#  ['6', '41', '2', '1', '3', 0],
#  ['4', '71', '2', '1', '3', 1],
#  ['4', '32', '2', '1', '3', 0],
#  ['4', '57', '2', '1', '3', 0],
#  ['4', '19', '1', '1', '3', 0],
#  ['4', '62', '2', '4', '3', 1],
#  ['5', '67', '4', '5', '3', 1],
#  ['4', '50', '4', '5', '3', 0],
#  ['4', '65', '2', '3', '2', 0],
#  ['4', '40', '2', '4', '2', 0],
#  ['6', '71', '4', '4', '3', 1],
#  ['6', '68', '4', '3', '3', 1],
#  ['4', '68', '1', '1', '3', 0],
#  ['4', '29', '1', '1', '3', 0],
#  ['4', '53', '2', '1', '3', 0],
#  ['5', '66', '4', '4', '3', 1],
#  ['4', '60', '3', '?', '4', 0],
#  ['5', '76', '4', '4', '3', 1],
#  ['4', '58', '2', '1', '2', 0],
#  ['5', '96', '3', '4', '3', 1],
#  ['5', '70', '4', '4', '3', 1],
#  ['4', '34', '2', '1', '3', 0],
#  ['4', '59', '2', '1', '3', 0],
#  ['4', '45', '3', '1', '3', 1],
#  ['5', '65', '4', '4', '3', 1],
#  ['4', '59', '1', '1', '3', 0],
#  ['4', '21', '2', '1', '3', 0],
#  ['3', '43', '2', '1', '3', 0],
#  ['4', '53', '1', '1', '3', 0],
#  ['4', '65', '2', '1', '3', 0],
#  ['4', '64', '2', '4', '3', 1],
#  ['4', '53', '4', '4', '3', 0],
#  ['4', '51', '1', '1', '3', 0],
#  ['4', '59', '2', '4', '3', 0],
#  ['4', '56', '2', '1', '3', 0],
#  ['4', '60', '2', '1', '3', 0],
#  ['4', '22', '1', '1', '3', 0],
#  ['4', '25', '2', '1', '3', 0],
#  ['6', '76', '3', '?', '3', 0],
#  ['5', '69', '4', '4', '3', 1],
#  ['4', '58', '2', '1', '3', 0],
#  ['5', '62', '4', '3', '3', 1],
#  ['4', '56', '4', '4', '3', 0],
#  ['4', '64', '1', '1', '3', 0],
#  ['4', '32', '2', '1', '3', 0],
#  ['5', '48', '?', '4', '?', 1],
#  ['5', '59', '4', '4', '2', 1],
#  ['4', '52', '1', '1', '3', 0],
#  ['4', '63', '4', '4', '3', 0],
#  ['5', '67', '4', '4', '3', 1],
#  ['5', '61', '4', '4', '3', 1],
#  ['5', '59', '4', '5', '3', 1],
#  ['5', '52', '4', '3', '3', 1],
#  ['4', '35', '4', '4', '3', 0],
#  ['5', '77', '3', '3', '3', 1],
#  ['5', '71', '4', '3', '3', 1],
#  ['5', '63', '4', '3', '3', 1],
#  ['4', '38', '2', '1', '2', 0],
#  ['5', '72', '4', '3', '3', 1],
#  ['4', '76', '4', '3', '3', 1],
#  ['4', '53', '3', '3', '3', 0],
#  ['4', '67', '4', '5', '3', 0],
#  ['5', '69', '2', '4', '3', 1],
#  ['4', '54', '1', '1', '3', 0],
#  ['2', '35', '2', '1', '2', 0],
#  ['5', '68', '4', '3', '3', 1],
#  ['4', '68', '4', '4', '3', 0],
#  ['4', '67', '2', '4', '3', 1],
#  ['3', '39', '1', '1', '3', 0],
#  ['4', '44', '2', '1', '3', 0],
#  ['4', '33', '1', '1', '3', 0],
#  ['4', '60', '?', '4', '3', 0],
#  ['4', '58', '1', '1', '3', 0],
#  ['4', '31', '1', '1', '3', 0],
#  ['3', '23', '1', '1', '3', 0],
#  ['5', '56', '4', '5', '3', 1],
#  ['4', '69', '2', '1', '3', 1],
#  ['6', '63', '1', '1', '3', 0],
#  ['4', '65', '1', '1', '3', 1],
#  ['4', '44', '2', '1', '2', 0],
#  ['4', '62', '3', '3', '3', 1],
#  ['4', '67', '4', '4', '3', 1],
#  ['4', '56', '2', '1', '3', 0],
#  ['4', '52', '3', '4', '3', 0],
#  ['4', '43', '1', '1', '3', 1],
#  ['4', '41', '4', '3', '2', 1],
#  ['4', '42', '3', '4', '2', 0],
#  ['3', '46', '1', '1', '3', 0],
#  ['5', '55', '4', '4', '3', 1],
#  ['5', '58', '4', '4', '2', 1],
#  ['5', '87', '4', '4', '3', 1],
#  ['4', '66', '2', '1', '3', 0],
#  ['0', '72', '4', '3', '3', 1],
#  ['5', '60', '4', '3', '3', 1],
#  ['5', '83', '4', '4', '2', 1],
#  ['4', '31', '2', '1', '3', 0],
#  ['4', '53', '2', '1', '3', 0],
#  ['4', '64', '2', '3', '3', 0],
#  ['5', '31', '4', '4', '2', 1],
#  ['5', '62', '4', '4', '2', 1],
#  ['4', '56', '2', '1', '3', 0],
#  ['5', '58', '4', '4', '3', 1],
#  ['4', '67', '1', '4', '3', 0],
#  ['5', '75', '4', '5', '3', 1],
#  ['5', '65', '3', '4', '3', 1],
#  ['5', '74', '3', '2', '3', 1],
#  ['4', '59', '2', '1', '3', 0],
#  ['4', '57', '4', '4', '4', 1],
#  ['4', '76', '3', '2', '3', 0],
#  ['4', '63', '1', '4', '3', 0],
#  ['4', '44', '1', '1', '3', 0],
#  ['4', '42', '3', '1', '2', 0],
#  ['4', '35', '3', '?', '2', 0],
#  ['5', '65', '4', '3', '3', 1],
#  ['4', '70', '2', '1', '3', 0],
#  ['4', '48', '1', '1', '3', 0],
#  ['4', '74', '1', '1', '1', 1],
#  ['6', '40', '?', '3', '4', 1],
#  ['4', '63', '1', '1', '3', 0],
#  ['5', '60', '4', '4', '3', 1],
#  ['5', '86', '4', '3', '3', 1],
#  ['4', '27', '1', '1', '3', 0],
#  ['4', '71', '4', '5', '2', 1],
#  ['5', '85', '4', '4', '3', 1],
#  ['4', '51', '3', '3', '3', 0],
#  ['6', '72', '4', '3', '3', 1],
#  ['5', '52', '4', '4', '3', 1],
#  ['4', '66', '2', '1', '3', 0],
#  ['5', '71', '4', '5', '3', 1],
#  ['4', '42', '2', '1', '3', 0],
#  ['4', '64', '4', '4', '2', 1],
#  ['4', '41', '2', '2', '3', 0],
#  ['4', '50', '2', '1', '3', 0],
#  ['4', '30', '1', '1', '3', 0],
#  ['4', '67', '1', '1', '3', 0],
#  ['5', '62', '4', '4', '3', 1],
#  ['4', '46', '2', '1', '2', 0],
#  ['4', '35', '1', '1', '3', 0],
#  ['4', '53', '1', '1', '2', 0],
#  ['4', '59', '2', '1', '3', 0],
#  ['4', '19', '3', '1', '3', 0],
#  ['5', '86', '2', '1', '3', 1],
#  ['4', '72', '2', '1', '3', 0],
#  ['4', '37', '2', '1', '2', 0],
#  ['4', '46', '3', '1', '3', 1],
#  ['4', '45', '1', '1', '3', 0],
#  ['4', '48', '4', '5', '3', 0],
#  ['4', '58', '4', '4', '3', 1],
#  ['4', '42', '1', '1', '3', 0],
#  ['4', '56', '2', '4', '3', 1],
#  ['4', '47', '2', '1', '3', 0],
#  ['4', '49', '4', '4', '3', 1],
#  ['5', '76', '2', '5', '3', 1],
#  ['5', '62', '4', '5', '3', 1],
#  ['5', '64', '4', '4', '3', 1],
#  ['5', '53', '4', '3', '3', 1],
#  ['4', '70', '4', '2', '2', 1],
#  ['5', '55', '4', '4', '3', 1],
#  ['4', '34', '4', '4', '3', 0],
#  ['5', '76', '4', '4', '3', 1],
#  ['4', '39', '1', '1', '3', 0],
#  ['2', '23', '1', '1', '3', 0],
#  ['4', '19', '1', '1', '3', 0],
#  ['5', '65', '4', '5', '3', 1],
#  ['4', '57', '2', '1', '3', 0],
#  ['5', '41', '4', '4', '3', 1],
#  ['4', '36', '4', '5', '3', 1],
#  ['4', '62', '3', '3', '3', 0],
#  ['4', '69', '2', '1', '3', 0],
#  ['4', '41', '3', '1', '3', 0],
#  ['3', '51', '2', '4', '3', 0],
#  ['5', '50', '3', '2', '3', 1],
#  ['4', '47', '4', '4', '3', 0],
#  ['4', '54', '4', '5', '3', 1],
#  ['5', '52', '4', '4', '3', 1],
#  ['4', '30', '1', '1', '3', 0],
#  ['3', '48', '4', '4', '3', 1],
#  ['5', '?', '4', '4', '3', 1],
#  ['4', '65', '2', '4', '3', 1],
#  ['4', '50', '1', '1', '3', 0],
#  ['5', '65', '4', '5', '3', 1],
#  ['5', '66', '4', '3', '3', 1],
#  ['6', '41', '3', '3', '2', 1],
#  ['5', '72', '3', '2', '3', 1],
#  ['4', '42', '1', '1', '1', 1],
#  ['4', '80', '4', '4', '3', 1],
#  ['0', '45', '2', '4', '3', 0],
#  ['4', '41', '1', '1', '3', 0],
#  ['4', '72', '3', '3', '3', 1],
#  ['4', '60', '4', '5', '3', 0],
#  ['5', '67', '4', '3', '3', 1],
#  ['4', '55', '2', '1', '3', 0],
#  ['4', '61', '3', '4', '3', 1],
#  ['4', '55', '3', '4', '3', 1],
#  ['4', '52', '4', '4', '3', 1],
#  ['4', '42', '1', '1', '3', 0],
#  ['5', '63', '4', '4', '3', 1],
#  ['4', '62', '4', '5', '3', 1],
#  ['4', '46', '1', '1', '3', 0],
#  ['4', '65', '2', '1', '3', 0],
#  ['4', '57', '3', '3', '3', 1],
#  ['4', '66', '4', '5', '3', 1],
#  ['4', '45', '1', '1', '3', 0],
#  ['4', '77', '4', '5', '3', 1],
#  ['4', '35', '1', '1', '3', 0],
#  ['4', '50', '4', '5', '3', 1],
#  ['4', '57', '4', '4', '3', 0],
#  ['4', '74', '3', '1', '3', 1],
#  ['4', '59', '4', '5', '3', 0],
#  ['4', '51', '1', '1', '3', 0],
#  ['4', '42', '3', '4', '3', 1],
#  ['4', '35', '2', '4', '3', 0],
#  ['4', '42', '1', '1', '3', 0],
#  ['4', '43', '2', '1', '3', 0],
#  ['4', '62', '4', '4', '3', 1],
#  ['4', '27', '2', '1', '3', 0],
#  ['5', '?', '4', '3', '3', 1],
#  ['4', '57', '4', '4', '3', 1],
#  ['4', '59', '2', '1', '3', 0],
#  ['5', '40', '3', '2', '3', 1],
#  ['4', '20', '1', '1', '3', 0],
#  ['5', '74', '4', '3', '3', 1],
#  ['4', '22', '1', '1', '3', 0],
#  ['4', '57', '4', '3', '3', 0],
#  ['4', '57', '4', '3', '3', 1],
#  ['4', '55', '2', '1', '2', 0],
#  ['4', '62', '2', '1', '3', 0],
#  ['4', '54', '1', '1', '3', 0],
#  ['4', '71', '1', '1', '3', 1],
#  ['4', '65', '3', '3', '3', 0],
#  ['4', '68', '4', '4', '3', 0],
#  ['4', '64', '1', '1', '3', 0],
#  ['4', '54', '2', '4', '3', 0],
#  ['4', '48', '4', '4', '3', 1],
#  ['4', '58', '4', '3', '3', 0],
#  ['5', '58', '3', '4', '3', 1],
#  ['4', '70', '1', '1', '1', 0],
#  ['5', '70', '1', '4', '3', 1],
#  ['4', '59', '2', '1', '3', 0],
#  ['4', '57', '2', '4', '3', 0],
#  ['4', '53', '4', '5', '3', 0],
#  ['4', '54', '4', '4', '3', 1],
#  ['4', '53', '2', '1', '3', 0],
#  ['0', '71', '4', '4', '3', 1],
#  ['5', '67', '4', '5', '3', 1],
#  ['4', '68', '4', '4', '3', 1],
#  ['4', '56', '2', '4', '3', 0],
#  ['4', '35', '2', '1', '3', 0],
#  ['4', '52', '4', '4', '3', 1],
#  ['4', '47', '2', '1', '3', 0],
#  ['4', '56', '4', '5', '3', 1],
#  ['4', '64', '4', '5', '3', 0],
#  ['5', '66', '4', '5', '3', 1],
#  ['4', '62', '3', '3', '3', 0]]

# %%
#adding attributes
for i in range(len(d)):
    for j in range (len(d[i])):
        d[i][j]=data.columns[j] + "=" +str(d[i][j])

d
# Out:
# [['BI-RADS=5', 'Age=67', 'Shape=3', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=43', 'Shape=1', 'Margin=1', 'Density=?', 'Severity=1'],
#  ['BI-RADS=5', 'Age=58', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=28', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=74', 'Shape=1', 'Margin=5', 'Density=?', 'Severity=1'],
#  ['BI-RADS=4', 'Age=65', 'Shape=1', 'Margin=?', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=70', 'Shape=?', 'Margin=?', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=42', 'Shape=1', 'Margin=?', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=57', 'Shape=1', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=60', 'Shape=?', 'Margin=5', 'Density=1', 'Severity=1'],
#  ['BI-RADS=5', 'Age=76', 'Shape=1', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=3', 'Age=42', 'Shape=2', 'Margin=1', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=64', 'Shape=1', 'Margin=?', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=36', 'Shape=3', 'Margin=1', 'Density=2', 'Severity=0'],
#  ['BI-RADS=4', 'Age=60', 'Shape=2', 'Margin=1', 'Density=2', 'Severity=0'],
#  ['BI-RADS=4', 'Age=54', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=3', 'Age=52', 'Shape=3', 'Margin=4', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=59', 'Shape=2', 'Margin=1', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=54', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=40', 'Shape=1', 'Margin=?', 'Density=?', 'Severity=0'],
#  ['BI-RADS=?', 'Age=66', 'Shape=?', 'Margin=?', 'Density=1', 'Severity=1'],
#  ['BI-RADS=5', 'Age=56', 'Shape=4', 'Margin=3', 'Density=1', 'Severity=1'],
#  ['BI-RADS=4', 'Age=43', 'Shape=1', 'Margin=?', 'Density=?', 'Severity=0'],
#  ['BI-RADS=5', 'Age=42', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=59', 'Shape=2', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=75', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=2', 'Age=66', 'Shape=1', 'Margin=1', 'Density=?', 'Severity=0'],
#  ['BI-RADS=5', 'Age=63', 'Shape=3', 'Margin=?', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=45', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=55', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=46', 'Shape=1', 'Margin=5', 'Density=2', 'Severity=0'],
#  ['BI-RADS=5', 'Age=54', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=57', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=39', 'Shape=1', 'Margin=1', 'Density=2', 'Severity=0'],
#  ['BI-RADS=4', 'Age=81', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=77', 'Shape=3', 'Margin=?', 'Density=?', 'Severity=0'],
#  ['BI-RADS=4', 'Age=60', 'Shape=2', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=67', 'Shape=3', 'Margin=4', 'Density=2', 'Severity=1'],
#  ['BI-RADS=4', 'Age=48', 'Shape=4', 'Margin=5', 'Density=?', 'Severity=1'],
#  ['BI-RADS=4', 'Age=55', 'Shape=3', 'Margin=4', 'Density=2', 'Severity=0'],
#  ['BI-RADS=4', 'Age=59', 'Shape=2', 'Margin=1', 'Density=?', 'Severity=0'],
#  ['BI-RADS=4', 'Age=78', 'Shape=1', 'Margin=1', 'Density=1', 'Severity=0'],
#  ['BI-RADS=4', 'Age=50', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=61', 'Shape=2', 'Margin=1', 'Density=?', 'Severity=0'],
#  ['BI-RADS=5', 'Age=62', 'Shape=3', 'Margin=5', 'Density=2', 'Severity=1'],
#  ['BI-RADS=5', 'Age=44', 'Shape=2', 'Margin=4', 'Density=?', 'Severity=1'],
#  ['BI-RADS=5', 'Age=64', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=23', 'Shape=1', 'Margin=1', 'Density=?', 'Severity=0'],
#  ['BI-RADS=2', 'Age=42', 'Shape=?', 'Margin=?', 'Density=4', 'Severity=0'],
#  ['BI-RADS=5', 'Age=67', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=74', 'Shape=2', 'Margin=1', 'Density=2', 'Severity=0'],
#  ['BI-RADS=5', 'Age=80', 'Shape=3', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=23', 'Shape=1', 'Margin=1', 'Density=?', 'Severity=0'],
#  ['BI-RADS=4', 'Age=63', 'Shape=2', 'Margin=1', 'Density=?', 'Severity=0'],
#  ['BI-RADS=4', 'Age=53', 'Shape=?', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=43', 'Shape=3', 'Margin=4', 'Density=?', 'Severity=0'],
#  ['BI-RADS=4', 'Age=49', 'Shape=2', 'Margin=1', 'Density=1', 'Severity=0'],
#  ['BI-RADS=5', 'Age=51', 'Shape=2', 'Margin=4', 'Density=?', 'Severity=0'],
#  ['BI-RADS=4', 'Age=45', 'Shape=2', 'Margin=1', 'Density=?', 'Severity=0'],
#  ['BI-RADS=5', 'Age=59', 'Shape=2', 'Margin=?', 'Density=?', 'Severity=1'],
#  ['BI-RADS=5', 'Age=52', 'Shape=4', 'Margin=3', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=60', 'Shape=4', 'Margin=3', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=57', 'Shape=2', 'Margin=5', 'Density=3', 'Severity=0'],
#  ['BI-RADS=3', 'Age=57', 'Shape=2', 'Margin=1', 'Density=?', 'Severity=0'],
#  ['BI-RADS=5', 'Age=74', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=25', 'Shape=2', 'Margin=1', 'Density=?', 'Severity=0'],
#  ['BI-RADS=4', 'Age=49', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=72', 'Shape=4', 'Margin=3', 'Density=?', 'Severity=1'],
#  ['BI-RADS=4', 'Age=45', 'Shape=2', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=64', 'Shape=2', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=73', 'Shape=2', 'Margin=1', 'Density=2', 'Severity=0'],
#  ['BI-RADS=5', 'Age=68', 'Shape=4', 'Margin=3', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=52', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=66', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=70', 'Shape=?', 'Margin=4', 'Density=?', 'Severity=1'],
#  ['BI-RADS=4', 'Age=25', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=74', 'Shape=1', 'Margin=1', 'Density=2', 'Severity=1'],
#  ['BI-RADS=4', 'Age=64', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=60', 'Shape=4', 'Margin=3', 'Density=2', 'Severity=1'],
#  ['BI-RADS=5', 'Age=67', 'Shape=2', 'Margin=4', 'Density=1', 'Severity=0'],
#  ['BI-RADS=4', 'Age=67', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=44', 'Shape=4', 'Margin=4', 'Density=2', 'Severity=1'],
#  ['BI-RADS=3', 'Age=68', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=57', 'Shape=?', 'Margin=4', 'Density=1', 'Severity=0'],
#  ['BI-RADS=5', 'Age=51', 'Shape=4', 'Margin=?', 'Density=?', 'Severity=1'],
#  ['BI-RADS=4', 'Age=33', 'Shape=1', 'Margin=?', 'Density=?', 'Severity=0'],
#  ['BI-RADS=5', 'Age=58', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=36', 'Shape=1', 'Margin=?', 'Density=?', 'Severity=0'],
#  ['BI-RADS=4', 'Age=63', 'Shape=1', 'Margin=1', 'Density=?', 'Severity=0'],
#  ['BI-RADS=5', 'Age=62', 'Shape=1', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=73', 'Shape=3', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=80', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=67', 'Shape=1', 'Margin=1', 'Density=?', 'Severity=0'],
#  ['BI-RADS=5', 'Age=59', 'Shape=2', 'Margin=1', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=60', 'Shape=1', 'Margin=?', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=54', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=40', 'Shape=1', 'Margin=1', 'Density=?', 'Severity=0'],
#  ['BI-RADS=4', 'Age=47', 'Shape=2', 'Margin=1', 'Density=?', 'Severity=0'],
#  ['BI-RADS=5', 'Age=62', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=33', 'Shape=2', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=59', 'Shape=2', 'Margin=?', 'Density=?', 'Severity=0'],
#  ['BI-RADS=4', 'Age=65', 'Shape=2', 'Margin=?', 'Density=?', 'Severity=0'],
#  ['BI-RADS=4', 'Age=58', 'Shape=4', 'Margin=4', 'Density=?', 'Severity=0'],
#  ['BI-RADS=4', 'Age=29', 'Shape=2', 'Margin=?', 'Density=?', 'Severity=0'],
#  ['BI-RADS=4', 'Age=58', 'Shape=1', 'Margin=1', 'Density=?', 'Severity=0'],
#  ['BI-RADS=4', 'Age=54', 'Shape=1', 'Margin=1', 'Density=?', 'Severity=0'],
#  ['BI-RADS=4', 'Age=44', 'Shape=1', 'Margin=1', 'Density=?', 'Severity=1'],
#  ['BI-RADS=3', 'Age=34', 'Shape=2', 'Margin=1', 'Density=?', 'Severity=0'],
#  ['BI-RADS=4', 'Age=57', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=33', 'Shape=4', 'Margin=4', 'Density=?', 'Severity=1'],
#  ['BI-RADS=4', 'Age=45', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=71', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=59', 'Shape=4', 'Margin=4', 'Density=2', 'Severity=0'],
#  ['BI-RADS=4', 'Age=56', 'Shape=2', 'Margin=1', 'Density=?', 'Severity=0'],
#  ['BI-RADS=4', 'Age=40', 'Shape=3', 'Margin=4', 'Density=?', 'Severity=0'],
#  ['BI-RADS=4', 'Age=56', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=45', 'Shape=2', 'Margin=1', 'Density=?', 'Severity=0'],
#  ['BI-RADS=4', 'Age=57', 'Shape=2', 'Margin=1', 'Density=2', 'Severity=0'],
#  ['BI-RADS=5', 'Age=55', 'Shape=3', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=84', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=51', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=43', 'Shape=1', 'Margin=1', 'Density=?', 'Severity=0'],
#  ['BI-RADS=4', 'Age=24', 'Shape=2', 'Margin=1', 'Density=2', 'Severity=0'],
#  ['BI-RADS=4', 'Age=66', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=33', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=59', 'Shape=4', 'Margin=3', 'Density=2', 'Severity=0'],
#  ['BI-RADS=4', 'Age=76', 'Shape=2', 'Margin=3', 'Density=?', 'Severity=0'],
#  ['BI-RADS=4', 'Age=40', 'Shape=1', 'Margin=1', 'Density=?', 'Severity=0'],
#  ['BI-RADS=4', 'Age=52', 'Shape=?', 'Margin=4', 'Density=?', 'Severity=0'],
#  ['BI-RADS=5', 'Age=40', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=67', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=75', 'Shape=4', 'Margin=3', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=86', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=60', 'Shape=2', 'Margin=?', 'Density=?', 'Severity=0'],
#  ['BI-RADS=5', 'Age=66', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=46', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=59', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=65', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=53', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=67', 'Shape=3', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=80', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=55', 'Shape=2', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=48', 'Shape=1', 'Margin=1', 'Density=?', 'Severity=0'],
#  ['BI-RADS=4', 'Age=47', 'Shape=1', 'Margin=1', 'Density=2', 'Severity=0'],
#  ['BI-RADS=4', 'Age=50', 'Shape=2', 'Margin=1', 'Density=?', 'Severity=0'],
#  ['BI-RADS=5', 'Age=62', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=63', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=63', 'Shape=4', 'Margin=?', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=71', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=41', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=57', 'Shape=4', 'Margin=4', 'Density=4', 'Severity=1'],
#  ['BI-RADS=5', 'Age=71', 'Shape=4', 'Margin=4', 'Density=4', 'Severity=1'],
#  ['BI-RADS=4', 'Age=66', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=47', 'Shape=2', 'Margin=4', 'Density=2', 'Severity=0'],
#  ['BI-RADS=3', 'Age=34', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=59', 'Shape=3', 'Margin=4', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=55', 'Shape=2', 'Margin=?', 'Density=?', 'Severity=1'],
#  ['BI-RADS=4', 'Age=51', 'Shape=?', 'Margin=?', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=62', 'Shape=2', 'Margin=1', 'Density=?', 'Severity=0'],
#  ['BI-RADS=4', 'Age=58', 'Shape=4', 'Margin=?', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=67', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=41', 'Shape=2', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=23', 'Shape=3', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=53', 'Shape=?', 'Margin=4', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=42', 'Shape=2', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=87', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=68', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=64', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=54', 'Shape=3', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=86', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=21', 'Shape=2', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=39', 'Shape=1', 'Margin=1', 'Density=?', 'Severity=0'],
#  ['BI-RADS=4', 'Age=53', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=44', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=54', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=63', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=62', 'Shape=2', 'Margin=1', 'Density=?', 'Severity=0'],
#  ['BI-RADS=4', 'Age=45', 'Shape=2', 'Margin=1', 'Density=2', 'Severity=0'],
#  ['BI-RADS=5', 'Age=71', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=49', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=49', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=66', 'Shape=4', 'Margin=4', 'Density=4', 'Severity=0'],
#  ['BI-RADS=4', 'Age=19', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=35', 'Shape=1', 'Margin=1', 'Density=2', 'Severity=0'],
#  ['BI-RADS=4', 'Age=71', 'Shape=3', 'Margin=3', 'Density=?', 'Severity=1'],
#  ['BI-RADS=5', 'Age=74', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=37', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=67', 'Shape=1', 'Margin=?', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=81', 'Shape=3', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=59', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=34', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=79', 'Shape=4', 'Margin=3', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=60', 'Shape=3', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=41', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=50', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=85', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=46', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=66', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=73', 'Shape=3', 'Margin=1', 'Density=2', 'Severity=0'],
#  ['BI-RADS=4', 'Age=55', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=49', 'Shape=2', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=3', 'Age=49', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=51', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=2', 'Age=48', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=58', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=72', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=46', 'Shape=2', 'Margin=3', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=43', 'Shape=4', 'Margin=3', 'Density=3', 'Severity=1'],
#  ['BI-RADS=?', 'Age=52', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=66', 'Shape=2', 'Margin=1', 'Density=?', 'Severity=0'],
#  ['BI-RADS=4', 'Age=46', 'Shape=1', 'Margin=1', 'Density=1', 'Severity=0'],
#  ['BI-RADS=4', 'Age=69', 'Shape=3', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=2', 'Age=59', 'Shape=1', 'Margin=1', 'Density=?', 'Severity=1'],
#  ['BI-RADS=5', 'Age=43', 'Shape=2', 'Margin=1', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=76', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=46', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=59', 'Shape=2', 'Margin=4', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=57', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=43', 'Shape=4', 'Margin=5', 'Density=?', 'Severity=0'],
#  ['BI-RADS=3', 'Age=45', 'Shape=2', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=3', 'Age=43', 'Shape=2', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=45', 'Shape=2', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=57', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=79', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=54', 'Shape=2', 'Margin=1', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=40', 'Shape=3', 'Margin=4', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=63', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=2', 'Age=55', 'Shape=1', 'Margin=?', 'Density=1', 'Severity=0'],
#  ['BI-RADS=4', 'Age=52', 'Shape=2', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=38', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=3', 'Age=72', 'Shape=4', 'Margin=3', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=80', 'Shape=4', 'Margin=3', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=76', 'Shape=4', 'Margin=3', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=62', 'Shape=3', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=64', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=42', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=0'],
#  ['BI-RADS=3', 'Age=60', 'Shape=?', 'Margin=3', 'Density=1', 'Severity=0'],
#  ['BI-RADS=4', 'Age=64', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=63', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=24', 'Shape=2', 'Margin=1', 'Density=2', 'Severity=0'],
#  ['BI-RADS=5', 'Age=72', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=63', 'Shape=2', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=46', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=3', 'Age=33', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=76', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=36', 'Shape=2', 'Margin=3', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=40', 'Shape=2', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=58', 'Shape=1', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=43', 'Shape=2', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=3', 'Age=42', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=32', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=57', 'Shape=4', 'Margin=4', 'Density=2', 'Severity=1'],
#  ['BI-RADS=4', 'Age=37', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=70', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=56', 'Shape=4', 'Margin=2', 'Density=3', 'Severity=1'],
#  ['BI-RADS=3', 'Age=76', 'Shape=?', 'Margin=3', 'Density=2', 'Severity=0'],
#  ['BI-RADS=5', 'Age=73', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=77', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=67', 'Shape=4', 'Margin=4', 'Density=1', 'Severity=1'],
#  ['BI-RADS=5', 'Age=71', 'Shape=4', 'Margin=3', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=65', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=43', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=40', 'Shape=2', 'Margin=1', 'Density=?', 'Severity=0'],
#  ['BI-RADS=4', 'Age=49', 'Shape=2', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=76', 'Shape=4', 'Margin=2', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=55', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=72', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=3', 'Age=53', 'Shape=4', 'Margin=3', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=75', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=61', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=67', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=55', 'Shape=4', 'Margin=2', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=66', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=2', 'Age=76', 'Shape=1', 'Margin=1', 'Density=2', 'Severity=0'],
#  ['BI-RADS=4', 'Age=57', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=71', 'Shape=3', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=70', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=35', 'Shape=4', 'Margin=2', 'Density=?', 'Severity=0'],
#  ['BI-RADS=5', 'Age=79', 'Shape=1', 'Margin=?', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=63', 'Shape=2', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=40', 'Shape=1', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=41', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=47', 'Shape=2', 'Margin=1', 'Density=2', 'Severity=0'],
#  ['BI-RADS=4', 'Age=68', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=64', 'Shape=4', 'Margin=3', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=65', 'Shape=4', 'Margin=4', 'Density=?', 'Severity=1'],
#  ['BI-RADS=4', 'Age=73', 'Shape=4', 'Margin=3', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=39', 'Shape=4', 'Margin=3', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=55', 'Shape=4', 'Margin=5', 'Density=4', 'Severity=1'],
#  ['BI-RADS=5', 'Age=53', 'Shape=3', 'Margin=4', 'Density=4', 'Severity=0'],
#  ['BI-RADS=5', 'Age=66', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=43', 'Shape=3', 'Margin=1', 'Density=2', 'Severity=0'],
#  ['BI-RADS=5', 'Age=44', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=77', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=62', 'Shape=2', 'Margin=4', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=80', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=33', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=50', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=71', 'Shape=1', 'Margin=?', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=46', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=49', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=53', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=3', 'Age=46', 'Shape=2', 'Margin=1', 'Density=2', 'Severity=0'],
#  ['BI-RADS=4', 'Age=57', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=54', 'Shape=3', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=54', 'Shape=1', 'Margin=?', 'Density=?', 'Severity=0'],
#  ['BI-RADS=2', 'Age=49', 'Shape=2', 'Margin=1', 'Density=2', 'Severity=0'],
#  ['BI-RADS=4', 'Age=47', 'Shape=3', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=40', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=45', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=50', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=54', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=67', 'Shape=4', 'Margin=1', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=77', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=66', 'Shape=4', 'Margin=3', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=71', 'Shape=2', 'Margin=?', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=36', 'Shape=2', 'Margin=3', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=69', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=48', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=64', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=71', 'Shape=4', 'Margin=2', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=60', 'Shape=4', 'Margin=3', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=24', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=34', 'Shape=4', 'Margin=5', 'Density=2', 'Severity=1'],
#  ['BI-RADS=4', 'Age=79', 'Shape=1', 'Margin=1', 'Density=2', 'Severity=0'],
#  ['BI-RADS=4', 'Age=45', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=37', 'Shape=2', 'Margin=1', 'Density=2', 'Severity=0'],
#  ['BI-RADS=4', 'Age=42', 'Shape=1', 'Margin=1', 'Density=2', 'Severity=0'],
#  ['BI-RADS=4', 'Age=72', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=60', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=85', 'Shape=3', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=51', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=54', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=55', 'Shape=4', 'Margin=3', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=64', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=67', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=75', 'Shape=4', 'Margin=3', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=87', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=46', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=59', 'Shape=2', 'Margin=1', 'Density=?', 'Severity=0'],
#  ['BI-RADS=5', 'Age=46', 'Shape=4', 'Margin=3', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=61', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=44', 'Shape=1', 'Margin=4', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=32', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=62', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=59', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=61', 'Shape=4', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=78', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=42', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=45', 'Shape=1', 'Margin=2', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=34', 'Shape=2', 'Margin=1', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=39', 'Shape=4', 'Margin=3', 'Density=?', 'Severity=1'],
#  ['BI-RADS=4', 'Age=27', 'Shape=3', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=43', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=83', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=36', 'Shape=2', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=37', 'Shape=2', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=56', 'Shape=3', 'Margin=1', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=55', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=46', 'Shape=3', 'Margin=?', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=88', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=71', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=41', 'Shape=2', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=49', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=3', 'Age=51', 'Shape=1', 'Margin=1', 'Density=4', 'Severity=0'],
#  ['BI-RADS=4', 'Age=39', 'Shape=1', 'Margin=3', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=46', 'Shape=2', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=52', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=58', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=67', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=80', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=3', 'Age=46', 'Shape=1', 'Margin=?', 'Density=?', 'Severity=0'],
#  ['BI-RADS=3', 'Age=43', 'Shape=1', 'Margin=?', 'Density=?', 'Severity=0'],
#  ['BI-RADS=4', 'Age=45', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=68', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=54', 'Shape=4', 'Margin=4', 'Density=?', 'Severity=1'],
#  ['BI-RADS=4', 'Age=44', 'Shape=2', 'Margin=3', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=74', 'Shape=4', 'Margin=3', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=55', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=49', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=49', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=50', 'Shape=4', 'Margin=3', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=52', 'Shape=3', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=45', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=66', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=68', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=72', 'Shape=2', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=64', 'Shape=?', 'Margin=?', 'Density=3', 'Severity=0'],
#  ['BI-RADS=2', 'Age=49', 'Shape=?', 'Margin=3', 'Density=3', 'Severity=0'],
#  ['BI-RADS=3', 'Age=44', 'Shape=?', 'Margin=4', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=74', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=58', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=77', 'Shape=2', 'Margin=3', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=49', 'Shape=3', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=34', 'Shape=?', 'Margin=?', 'Density=4', 'Severity=0'],
#  ['BI-RADS=5', 'Age=60', 'Shape=4', 'Margin=3', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=69', 'Shape=4', 'Margin=3', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=53', 'Shape=2', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=3', 'Age=46', 'Shape=3', 'Margin=4', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=74', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=58', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=68', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=46', 'Shape=4', 'Margin=3', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=61', 'Shape=2', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=70', 'Shape=4', 'Margin=3', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=37', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=3', 'Age=65', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=67', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=69', 'Shape=3', 'Margin=4', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=76', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=65', 'Shape=4', 'Margin=3', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=72', 'Shape=4', 'Margin=2', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=62', 'Shape=4', 'Margin=2', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=42', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=66', 'Shape=4', 'Margin=3', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=48', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=35', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=60', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=67', 'Shape=4', 'Margin=2', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=78', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=66', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=26', 'Shape=1', 'Margin=1', 'Density=?', 'Severity=0'],
#  ['BI-RADS=4', 'Age=48', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=31', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=43', 'Shape=4', 'Margin=3', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=72', 'Shape=2', 'Margin=4', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=66', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=56', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=58', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=33', 'Shape=2', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=37', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=36', 'Shape=4', 'Margin=3', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=39', 'Shape=2', 'Margin=3', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=39', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=83', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=68', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=63', 'Shape=3', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=78', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=38', 'Shape=2', 'Margin=3', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=46', 'Shape=4', 'Margin=3', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=60', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=56', 'Shape=2', 'Margin=3', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=33', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=?', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=69', 'Shape=1', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=66', 'Shape=1', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=72', 'Shape=1', 'Margin=3', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=29', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=54', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=80', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=68', 'Shape=4', 'Margin=3', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=35', 'Shape=2', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=57', 'Shape=3', 'Margin=?', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=?', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=50', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=32', 'Shape=4', 'Margin=3', 'Density=3', 'Severity=0'],
#  ['BI-RADS=0', 'Age=69', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=71', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=87', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=3', 'Age=40', 'Shape=2', 'Margin=?', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=31', 'Shape=1', 'Margin=1', 'Density=?', 'Severity=0'],
#  ['BI-RADS=4', 'Age=64', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=55', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=18', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=3', 'Age=50', 'Shape=2', 'Margin=1', 'Density=?', 'Severity=0'],
#  ['BI-RADS=4', 'Age=53', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=84', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=80', 'Shape=4', 'Margin=3', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=32', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=77', 'Shape=3', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=38', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=54', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=63', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=61', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=52', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=36', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=41', 'Shape=?', 'Margin=?', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=59', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=51', 'Shape=4', 'Margin=4', 'Density=2', 'Severity=1'],
#  ['BI-RADS=4', 'Age=36', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=40', 'Shape=4', 'Margin=3', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=49', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=37', 'Shape=2', 'Margin=3', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=46', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=63', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=28', 'Shape=2', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=47', 'Shape=2', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=42', 'Shape=2', 'Margin=1', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=44', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=49', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=47', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=52', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=53', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=83', 'Shape=3', 'Margin=3', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=50', 'Shape=4', 'Margin=4', 'Density=?', 'Severity=1'],
#  ['BI-RADS=5', 'Age=63', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=82', 'Shape=?', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=54', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=50', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=80', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=45', 'Shape=2', 'Margin=4', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=59', 'Shape=4', 'Margin=4', 'Density=?', 'Severity=1'],
#  ['BI-RADS=4', 'Age=28', 'Shape=2', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=31', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=41', 'Shape=2', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=21', 'Shape=3', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=44', 'Shape=3', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=49', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=71', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=75', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=38', 'Shape=2', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=60', 'Shape=1', 'Margin=3', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=87', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=70', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=55', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=3', 'Age=21', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=50', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=76', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=23', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=3', 'Age=68', 'Shape=?', 'Margin=?', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=62', 'Shape=4', 'Margin=?', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=65', 'Shape=1', 'Margin=?', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=73', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=38', 'Shape=2', 'Margin=3', 'Density=3', 'Severity=0'],
#  ['BI-RADS=2', 'Age=57', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=65', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=67', 'Shape=2', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=61', 'Shape=2', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=56', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=71', 'Shape=2', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=49', 'Shape=2', 'Margin=2', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=55', 'Shape=?', 'Margin=?', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=44', 'Shape=2', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=0', 'Age=58', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=27', 'Shape=2', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=73', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=34', 'Shape=2', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=63', 'Shape=?', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=50', 'Shape=2', 'Margin=1', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=62', 'Shape=2', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=3', 'Age=21', 'Shape=3', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=49', 'Shape=2', 'Margin=?', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=36', 'Shape=3', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=45', 'Shape=2', 'Margin=1', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=67', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=21', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=57', 'Shape=2', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=66', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=71', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=69', 'Shape=3', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=6', 'Age=80', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=3', 'Age=27', 'Shape=2', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=38', 'Shape=2', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=23', 'Shape=2', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=70', 'Shape=?', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=46', 'Shape=4', 'Margin=3', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=61', 'Shape=2', 'Margin=3', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=65', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=60', 'Shape=4', 'Margin=3', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=83', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=40', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=2', 'Age=59', 'Shape=?', 'Margin=4', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=53', 'Shape=3', 'Margin=4', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=76', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=79', 'Shape=1', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=38', 'Shape=2', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=61', 'Shape=3', 'Margin=4', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=56', 'Shape=2', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=44', 'Shape=2', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=64', 'Shape=3', 'Margin=4', 'Density=?', 'Severity=1'],
#  ['BI-RADS=4', 'Age=66', 'Shape=3', 'Margin=3', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=50', 'Shape=3', 'Margin=3', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=46', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=39', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=60', 'Shape=3', 'Margin=?', 'Density=?', 'Severity=0'],
#  ['BI-RADS=5', 'Age=55', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=40', 'Shape=2', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=26', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=84', 'Shape=3', 'Margin=2', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=41', 'Shape=2', 'Margin=2', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=63', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=2', 'Age=65', 'Shape=?', 'Margin=1', 'Density=2', 'Severity=0'],
#  ['BI-RADS=4', 'Age=49', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=56', 'Shape=2', 'Margin=2', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=65', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=54', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=36', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=49', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=59', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=75', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=59', 'Shape=4', 'Margin=2', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=59', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=28', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=53', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=57', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=77', 'Shape=4', 'Margin=3', 'Density=4', 'Severity=0'],
#  ['BI-RADS=5', 'Age=85', 'Shape=4', 'Margin=3', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=59', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=59', 'Shape=1', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=65', 'Shape=3', 'Margin=3', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=54', 'Shape=2', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=46', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=63', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=53', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=56', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=66', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=66', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=55', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=44', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=86', 'Shape=3', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=47', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=59', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=66', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=61', 'Shape=4', 'Margin=3', 'Density=3', 'Severity=1'],
#  ['BI-RADS=3', 'Age=46', 'Shape=?', 'Margin=5', 'Density=?', 'Severity=1'],
#  ['BI-RADS=4', 'Age=69', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=93', 'Shape=1', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=39', 'Shape=1', 'Margin=3', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=44', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=45', 'Shape=2', 'Margin=2', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=51', 'Shape=3', 'Margin=4', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=56', 'Shape=2', 'Margin=4', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=66', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=61', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=64', 'Shape=3', 'Margin=3', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=57', 'Shape=2', 'Margin=4', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=79', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=57', 'Shape=2', 'Margin=1', 'Density=?', 'Severity=0'],
#  ['BI-RADS=4', 'Age=44', 'Shape=4', 'Margin=1', 'Density=1', 'Severity=0'],
#  ['BI-RADS=4', 'Age=31', 'Shape=2', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=63', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=0'],
# ...
#  ['BI-RADS=4', 'Age=32', 'Shape=2', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=48', 'Shape=?', 'Margin=4', 'Density=?', 'Severity=1'],
#  ['BI-RADS=5', 'Age=59', 'Shape=4', 'Margin=4', 'Density=2', 'Severity=1'],
#  ['BI-RADS=4', 'Age=52', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=63', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=67', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=61', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=59', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=52', 'Shape=4', 'Margin=3', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=35', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=77', 'Shape=3', 'Margin=3', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=71', 'Shape=4', 'Margin=3', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=63', 'Shape=4', 'Margin=3', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=38', 'Shape=2', 'Margin=1', 'Density=2', 'Severity=0'],
#  ['BI-RADS=5', 'Age=72', 'Shape=4', 'Margin=3', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=76', 'Shape=4', 'Margin=3', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=53', 'Shape=3', 'Margin=3', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=67', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=69', 'Shape=2', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=54', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=2', 'Age=35', 'Shape=2', 'Margin=1', 'Density=2', 'Severity=0'],
#  ['BI-RADS=5', 'Age=68', 'Shape=4', 'Margin=3', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=68', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=67', 'Shape=2', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=3', 'Age=39', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=44', 'Shape=2', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=33', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=60', 'Shape=?', 'Margin=4', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=58', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=31', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=3', 'Age=23', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=56', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=69', 'Shape=2', 'Margin=1', 'Density=3', 'Severity=1'],
#  ['BI-RADS=6', 'Age=63', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=65', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=44', 'Shape=2', 'Margin=1', 'Density=2', 'Severity=0'],
#  ['BI-RADS=4', 'Age=62', 'Shape=3', 'Margin=3', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=67', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=56', 'Shape=2', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=52', 'Shape=3', 'Margin=4', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=43', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=41', 'Shape=4', 'Margin=3', 'Density=2', 'Severity=1'],
#  ['BI-RADS=4', 'Age=42', 'Shape=3', 'Margin=4', 'Density=2', 'Severity=0'],
#  ['BI-RADS=3', 'Age=46', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=55', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=58', 'Shape=4', 'Margin=4', 'Density=2', 'Severity=1'],
#  ['BI-RADS=5', 'Age=87', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=66', 'Shape=2', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=0', 'Age=72', 'Shape=4', 'Margin=3', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=60', 'Shape=4', 'Margin=3', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=83', 'Shape=4', 'Margin=4', 'Density=2', 'Severity=1'],
#  ['BI-RADS=4', 'Age=31', 'Shape=2', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=53', 'Shape=2', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=64', 'Shape=2', 'Margin=3', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=31', 'Shape=4', 'Margin=4', 'Density=2', 'Severity=1'],
#  ['BI-RADS=5', 'Age=62', 'Shape=4', 'Margin=4', 'Density=2', 'Severity=1'],
#  ['BI-RADS=4', 'Age=56', 'Shape=2', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=58', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=67', 'Shape=1', 'Margin=4', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=75', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=65', 'Shape=3', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=74', 'Shape=3', 'Margin=2', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=59', 'Shape=2', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=57', 'Shape=4', 'Margin=4', 'Density=4', 'Severity=1'],
#  ['BI-RADS=4', 'Age=76', 'Shape=3', 'Margin=2', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=63', 'Shape=1', 'Margin=4', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=44', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=42', 'Shape=3', 'Margin=1', 'Density=2', 'Severity=0'],
#  ['BI-RADS=4', 'Age=35', 'Shape=3', 'Margin=?', 'Density=2', 'Severity=0'],
#  ['BI-RADS=5', 'Age=65', 'Shape=4', 'Margin=3', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=70', 'Shape=2', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=48', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=74', 'Shape=1', 'Margin=1', 'Density=1', 'Severity=1'],
#  ['BI-RADS=6', 'Age=40', 'Shape=?', 'Margin=3', 'Density=4', 'Severity=1'],
#  ['BI-RADS=4', 'Age=63', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=60', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=86', 'Shape=4', 'Margin=3', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=27', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=71', 'Shape=4', 'Margin=5', 'Density=2', 'Severity=1'],
#  ['BI-RADS=5', 'Age=85', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=51', 'Shape=3', 'Margin=3', 'Density=3', 'Severity=0'],
#  ['BI-RADS=6', 'Age=72', 'Shape=4', 'Margin=3', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=52', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=66', 'Shape=2', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=71', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=42', 'Shape=2', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=64', 'Shape=4', 'Margin=4', 'Density=2', 'Severity=1'],
#  ['BI-RADS=4', 'Age=41', 'Shape=2', 'Margin=2', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=50', 'Shape=2', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=30', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=67', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=62', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=46', 'Shape=2', 'Margin=1', 'Density=2', 'Severity=0'],
#  ['BI-RADS=4', 'Age=35', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=53', 'Shape=1', 'Margin=1', 'Density=2', 'Severity=0'],
#  ['BI-RADS=4', 'Age=59', 'Shape=2', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=19', 'Shape=3', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=86', 'Shape=2', 'Margin=1', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=72', 'Shape=2', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=37', 'Shape=2', 'Margin=1', 'Density=2', 'Severity=0'],
#  ['BI-RADS=4', 'Age=46', 'Shape=3', 'Margin=1', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=45', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=48', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=58', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=42', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=56', 'Shape=2', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=47', 'Shape=2', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=49', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=76', 'Shape=2', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=62', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=64', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=53', 'Shape=4', 'Margin=3', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=70', 'Shape=4', 'Margin=2', 'Density=2', 'Severity=1'],
#  ['BI-RADS=5', 'Age=55', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=34', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=76', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=39', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=2', 'Age=23', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=19', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=65', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=57', 'Shape=2', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=41', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=36', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=62', 'Shape=3', 'Margin=3', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=69', 'Shape=2', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=41', 'Shape=3', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=3', 'Age=51', 'Shape=2', 'Margin=4', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=50', 'Shape=3', 'Margin=2', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=47', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=54', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=52', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=30', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=3', 'Age=48', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=?', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=65', 'Shape=2', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=50', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=65', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=66', 'Shape=4', 'Margin=3', 'Density=3', 'Severity=1'],
#  ['BI-RADS=6', 'Age=41', 'Shape=3', 'Margin=3', 'Density=2', 'Severity=1'],
#  ['BI-RADS=5', 'Age=72', 'Shape=3', 'Margin=2', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=42', 'Shape=1', 'Margin=1', 'Density=1', 'Severity=1'],
#  ['BI-RADS=4', 'Age=80', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=0', 'Age=45', 'Shape=2', 'Margin=4', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=41', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=72', 'Shape=3', 'Margin=3', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=60', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=67', 'Shape=4', 'Margin=3', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=55', 'Shape=2', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=61', 'Shape=3', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=55', 'Shape=3', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=52', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=42', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=63', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=62', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=46', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=65', 'Shape=2', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=57', 'Shape=3', 'Margin=3', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=66', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=45', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=77', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=35', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=50', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=57', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=74', 'Shape=3', 'Margin=1', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=59', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=51', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=42', 'Shape=3', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=35', 'Shape=2', 'Margin=4', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=42', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=43', 'Shape=2', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=62', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=27', 'Shape=2', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=?', 'Shape=4', 'Margin=3', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=57', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=59', 'Shape=2', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=40', 'Shape=3', 'Margin=2', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=20', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=74', 'Shape=4', 'Margin=3', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=22', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=57', 'Shape=4', 'Margin=3', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=57', 'Shape=4', 'Margin=3', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=55', 'Shape=2', 'Margin=1', 'Density=2', 'Severity=0'],
#  ['BI-RADS=4', 'Age=62', 'Shape=2', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=54', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=71', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=65', 'Shape=3', 'Margin=3', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=68', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=64', 'Shape=1', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=54', 'Shape=2', 'Margin=4', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=48', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=58', 'Shape=4', 'Margin=3', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=58', 'Shape=3', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=70', 'Shape=1', 'Margin=1', 'Density=1', 'Severity=0'],
#  ['BI-RADS=5', 'Age=70', 'Shape=1', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=59', 'Shape=2', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=57', 'Shape=2', 'Margin=4', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=53', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=54', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=53', 'Shape=2', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=0', 'Age=71', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=5', 'Age=67', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=68', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=56', 'Shape=2', 'Margin=4', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=35', 'Shape=2', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=52', 'Shape=4', 'Margin=4', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=47', 'Shape=2', 'Margin=1', 'Density=3', 'Severity=0'],
#  ['BI-RADS=4', 'Age=56', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=64', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=0'],
#  ['BI-RADS=5', 'Age=66', 'Shape=4', 'Margin=5', 'Density=3', 'Severity=1'],
#  ['BI-RADS=4', 'Age=62', 'Shape=3', 'Margin=3', 'Density=3', 'Severity=0']]

# %%
te = TransactionEncoder()
te_ary = te.fit(d).transform(d)

df = pd.DataFrame(te_ary, columns=te.columns_)
#this part needs to be filled...
# Out:
#      Age=18  Age=19  Age=20  Age=21  Age=22  Age=23  Age=24  Age=25  Age=26  \
# 0     False   False   False   False   False   False   False   False   False
# 1     False   False   False   False   False   False   False   False   False
# 2     False   False   False   False   False   False   False   False   False
# 3     False   False   False   False   False   False   False   False   False
# 4     False   False   False   False   False   False   False   False   False
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 956   False   False   False   False   False   False   False   False   False
# 957   False   False   False   False   False   False   False   False   False
# 958   False   False   False   False   False   False   False   False   False
# 959   False   False   False   False   False   False   False   False   False
# 960   False   False   False   False   False   False   False   False   False
#
#      Age=27  ...  Margin=4  Margin=5  Margin=?  Severity=0  Severity=1  \
# 0     False  ...     False      True     False       False        True
# 1     False  ...     False     False     False       False        True
# 2     False  ...     False      True     False       False        True
# 3     False  ...     False     False     False        True       False
# 4     False  ...     False      True     False       False        True
# ..      ...  ...       ...       ...       ...         ...         ...
# 956   False  ...     False     False     False        True       False
# 957   False  ...     False      True     False       False        True
# 958   False  ...     False      True     False        True       False
# 959   False  ...     False      True     False       False        True
# 960   False  ...     False     False     False        True       False
#
#      Shape=1  Shape=2  Shape=3  Shape=4  Shape=?
# 0      False    False     True    False    False
# 1       True    False    False    False    False
# 2      False    False    False     True    False
# 3       True    False    False    False    False
# 4       True    False    False    False    False
# ..       ...      ...      ...      ...      ...
# 956    False     True    False    False    False
# 957    False    False    False     True    False
# 958    False    False    False     True    False
# 959    False    False    False     True    False
# 960    False    False     True    False    False
#
# [961 rows x 99 columns]
